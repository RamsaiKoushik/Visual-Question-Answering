# %%
# %pip install pandas
# Out:
# Collecting pandas
#   Downloading pandas-2.2.2-cp310-cp310-win_amd64.whl (11.6 MB)
# Collecting pytz>=2020.1
#   Using cached pytz-2024.1-py2.py3-none-any.whl (505 kB)
# Collecting numpy>=1.22.4
#   Downloading numpy-1.26.4-cp310-cp310-win_amd64.whl (15.8 MB)
# Collecting tzdata>=2022.7
#   Using cached tzdata-2024.1-py2.py3-none-any.whl (345 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\p.ramsai koushik\appdata\roaming\python\python310\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\p.ramsai koushik\appdata\roaming\python\python310\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Installing collected packages: tzdata, pytz, numpy, pandas
# Successfully installed numpy-1.26.4 pandas-2.2.2 pytz-2024.1 tzdata-2024.1
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script f2py.exe is installed in 'c:\Users\P.Ramsai Koushik\AppData\Local\Programs\Python\Python310\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# WARNING: You are using pip version 21.2.3; however, version 24.0 is available.
# You should consider upgrading via the 'c:\Users\P.Ramsai Koushik\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %% [markdown]
# # Dataset Preprocessing

# %%
import os
import pandas as pd

# %% [markdown]
# ### Create a dataframe to store the metadata of train images

# %% [markdown]
# Create a dataframe with image_name, image_id, image_path, hashed_image_id(this is used for random sampling)

# %%
# Path to the folder containing the image files
folder_path = "train2014"

# Get a list of all files in the folder
files = os.listdir(folder_path)

# Filter out only the image files
image_files = [file for file in files if file.endswith('.jpg')]

# Extract the image number from the file name
image_numbers = [int(file.split('_')[-1].split('.')[0]) for file in image_files]

# Create a DataFrame
df = pd.DataFrame({
    'image_name': image_files,
    'image_path': [os.path.join(folder_path, file) for file in image_files],
    'image_id': image_numbers
})

# Sort the DataFrame by numbers
df_sorted = df.sort_values(by='image_id').reset_index(drop=True)

# Create a mapping dictionary
mapping = {number: index + 1 for index, number in enumerate(df_sorted['image_id'])}

def custom_hash(x):
    return mapping[x]

df['hashed_image_id'] = df['image_id'].apply(custom_hash)

# Sort the DataFrame by hashed number
df.sort_values(by='hashed_image_id', inplace=True)

# Reset index to make sure it's sequential
df.reset_index(drop=True, inplace=True)

# Display the DataFrame
print(df.head())
# Out:
#                         image_name                                 image_path  \
# 0  COCO_train2014_000000000009.jpg  train2014\COCO_train2014_000000000009.jpg
# 1  COCO_train2014_000000000025.jpg  train2014\COCO_train2014_000000000025.jpg
# 2  COCO_train2014_000000000030.jpg  train2014\COCO_train2014_000000000030.jpg
# 3  COCO_train2014_000000000034.jpg  train2014\COCO_train2014_000000000034.jpg
# 4  COCO_train2014_000000000036.jpg  train2014\COCO_train2014_000000000036.jpg
#
#    image_id  hashed_image_id
# 0         9                1
# 1        25                2
# 2        30                3
# 3        34                4
# 4        36                5

# %%
print(max(df['hashed_image_id']))
# Out:
# 82783

# %%
df.to_csv('train_images.csv',index=False)

# %%
#### C

# %% [markdown]
# #### Random Sampling of dataset (tain images)

# %% [markdown]
# Create 20,695(25 percent of 82,783) random indices in between 1 and 82,783

# %%
import random

random.seed(42) # ensures that we get the same random indices everytime we run the notebook

# Number of indices
num_indices = len(df)//4

# Range of numbers
num_range = df['hashed_image_id'].max()

# Generate a list of random indices
random_indices = random.sample(range(1, num_range + 1), num_indices)

# Create a new DataFrame containing rows where the hashed number is present in the random indices list
sampled_df = df[df['hashed_image_id'].isin(random_indices)].reset_index(drop=True)

print(sampled_df.head())
# Out:
#                         image_name                                 image_path  \
# 0  COCO_train2014_000000000025.jpg  train2014\COCO_train2014_000000000025.jpg
# 1  COCO_train2014_000000000036.jpg  train2014\COCO_train2014_000000000036.jpg
# 2  COCO_train2014_000000000064.jpg  train2014\COCO_train2014_000000000064.jpg
# 3  COCO_train2014_000000000078.jpg  train2014\COCO_train2014_000000000078.jpg
# 4  COCO_train2014_000000000081.jpg  train2014\COCO_train2014_000000000081.jpg
#
#    image_id  hashed_image_id
# 0        25                2
# 1        36                5
# 2        64                8
# 3        78               12
# 4        81               13

# %%
print(len(sampled_df), min(sampled_df['hashed_image_id']),max(sampled_df['hashed_image_id']))
# Out:
# 20695 2 82782

# %%
sampled_df.to_csv('sampled_train_images.csv',index=False)

# %% [markdown]
# ### Store the questions in csv format

# %%
import json
# Read the JSON file
with open('v2_Questions_Train_mscoco/v2_OpenEnded_mscoco_train2014_questions.json', 'r') as f:
    questions_data = json.load(f)

# %%
questions_data['questions']
# Out:
# [{'image_id': 458752,
#   'question': 'What is this photo taken looking through?',
#   'question_id': 458752000},
#  {'image_id': 458752,
#   'question': 'What position is this man playing?',
#   'question_id': 458752001},
#  {'image_id': 458752,
#   'question': 'What color is the players shirt?',
#   'question_id': 458752002},
#  {'image_id': 458752,
#   'question': 'Is this man a professional baseball player?',
#   'question_id': 458752003},
#  {'image_id': 262146,
#   'question': 'What color is the snow?',
#   'question_id': 262146000},
#  {'image_id': 262146,
#   'question': 'What is the person doing?',
#   'question_id': 262146001},
#  {'image_id': 262146,
#   'question': 'What color is the persons headwear?',
#   'question_id': 262146002},
#  {'image_id': 524291,
#   'question': "What is in the person's hand?",
#   'question_id': 524291000},
#  {'image_id': 524291,
#   'question': 'Is the dog waiting?',
#   'question_id': 524291001},
#  {'image_id': 524291,
#   'question': 'Is the dog looking at a tennis ball or frisbee?',
#   'question_id': 524291002},
#  {'image_id': 393221,
#   'question': 'Is the sky blue?',
#   'question_id': 393221000},
#  {'image_id': 393221,
#   'question': 'Is there snow on the mountains?',
#   'question_id': 393221001},
#  {'image_id': 393221,
#   'question': 'What is the white streak?',
#   'question_id': 393221002},
#  {'image_id': 393223,
#   'question': 'Is the window open?',
#   'question_id': 393223000},
#  {'image_id': 393223,
#   'question': 'What color is the toothbrush?',
#   'question_id': 393223001},
#  {'image_id': 393223,
#   'question': 'What is the child doing?',
#   'question_id': 393223002},
#  {'image_id': 393223,
#   'question': 'Is she brushing?',
#   'question_id': 393223003},
#  {'image_id': 393224,
#   'question': 'Is the man smiling?',
#   'question_id': 393224000},
#  {'image_id': 393224,
#   'question': 'What is the business man doing in the picture?',
#   'question_id': 393224001},
#  {'image_id': 393224,
#   'question': 'Does his tie pair well with his suit?',
#   'question_id': 393224002},
#  {'image_id': 393224,
#   'question': 'Does the man look happy?',
#   'question_id': 393224003},
#  {'image_id': 393224,
#   'question': 'Is this photo in color?',
#   'question_id': 393224004},
#  {'image_id': 393224,
#   'question': 'Is the man wearing a plain tie?',
#   'question_id': 393224005},
#  {'image_id': 524297,
#   'question': 'Judging from the dress, was this taken in a Latin American country?',
#   'question_id': 524297000},
#  {'image_id': 524297,
#   'question': 'What colors are shown in this picture?',
#   'question_id': 524297001},
#  {'image_id': 524297,
#   'question': 'Are the men on the sidewalk?',
#   'question_id': 524297002},
#  {'image_id': 524297,
#   'question': 'Was this photo taken recently?',
#   'question_id': 524297003},
#  {'image_id': 393227,
#   'question': 'Does the guy have a tattoo?',
#   'question_id': 393227000},
#  {'image_id': 393227,
#   'question': 'What is this man riding on?',
#   'question_id': 393227001},
#  {'image_id': 393227,
#   'question': "How many tattoos can be seen on this man's body?",
#   'question_id': 393227002},
#  {'image_id': 393227,
#   'question': 'What color is his hat?',
#   'question_id': 393227003},
#  {'image_id': 393227,
#   'question': "Is the man's visor providing his face enough protection?",
#   'question_id': 393227004},
#  {'image_id': 131084,
#   'question': 'What color is the jacket?',
#   'question_id': 131084000},
#  {'image_id': 131084,
#   'question': 'Is the man riding on a dirt path?',
#   'question_id': 131084001},
#  {'image_id': 131084,
#   'question': 'What is the man riding on?',
#   'question_id': 131084002},
#  {'image_id': 131074,
#   'question': 'What is on the pillow?',
#   'question_id': 131074000},
#  {'image_id': 131074,
#   'question': 'How many pieces of furniture which are used for sleeping are featured in this picture?',
#   'question_id': 131074001},
#  {'image_id': 131074,
#   'question': 'Are the walls done in a summery color?',
#   'question_id': 131074002},
#  {'image_id': 131074,
#   'question': 'Is the curtain patterned?',
#   'question_id': 131074003},
#  {'image_id': 131074,
#   'question': 'What is sitting on the bench?',
#   'question_id': 131074004},
#  {'image_id': 131074,
#   'question': 'Are the windows the same size?',
#   'question_id': 131074005},
#  {'image_id': 393230,
#   'question': 'What is this person doing?',
#   'question_id': 393230000},
#  {'image_id': 393230,
#   'question': 'How many people are in this image?',
#   'question_id': 393230001},
#  {'image_id': 393230,
#   'question': 'Is there a shadow of a tree in the foreground?',
#   'question_id': 393230002},
#  {'image_id': 393230,
#   'question': 'What is the man doing?',
#   'question_id': 393230003},
#  {'image_id': 393230,
#   'question': 'What color is the sky?',
#   'question_id': 393230004},
#  {'image_id': 393230,
#   'question': 'What is the person wearing?',
#   'question_id': 393230005},
#  {'image_id': 393230,
#   'question': 'Did someone forget his luggage in the snow?',
#   'question_id': 393230006},
#  {'image_id': 393230,
#   'question': 'What color is his coat?',
#   'question_id': 393230007},
#  {'image_id': 393230, 'question': 'Is it daytime?', 'question_id': 393230008},
#  {'image_id': 393230,
#   'question': 'What is she holding?',
#   'question_id': 393230009},
#  {'image_id': 393230,
#   'question': 'Is the person wearing a hat?',
#   'question_id': 393230010},
#  {'image_id': 131087,
#   'question': 'What is the dog riding on?',
#   'question_id': 131087000},
#  {'image_id': 131087,
#   'question': 'Is the dog wearing a collar?',
#   'question_id': 131087001},
#  {'image_id': 131087,
#   'question': 'Is it a clear day?',
#   'question_id': 131087002},
#  {'image_id': 131087,
#   'question': 'Is there a body of water here?',
#   'question_id': 131087003},
#  {'image_id': 131087,
#   'question': 'What is in the water?',
#   'question_id': 131087004},
#  {'image_id': 131075,
#   'question': 'What does the green light, on the TV, indicate?',
#   'question_id': 131075000},
#  {'image_id': 131075,
#   'question': 'Is the light on?',
#   'question_id': 131075001},
#  {'image_id': 131075,
#   'question': 'What room of the house is this?',
#   'question_id': 131075002},
#  {'image_id': 131075,
#   'question': 'What is the size of the TV?',
#   'question_id': 131075003},
#  {'image_id': 131075,
#   'question': 'Is the room messy?',
#   'question_id': 131075004},
#  {'image_id': 131075,
#   'question': 'Is this a TV screen?',
#   'question_id': 131075005},
#  {'image_id': 131075,
#   'question': 'How big is the TV?',
#   'question_id': 131075006},
#  {'image_id': 131075,
#   'question': 'What companion object to the TV can be seen in the bottom right of the picture?',
#   'question_id': 131075007},
#  {'image_id': 131075,
#   'question': 'What is the small computer on the left called?',
#   'question_id': 131075008},
#  {'image_id': 131075,
#   'question': 'What is above the TV?',
#   'question_id': 131075009},
#  {'image_id': 131075,
#   'question': 'What is on the display?',
#   'question_id': 131075010},
#  {'image_id': 131075,
#   'question': 'Is there a laptop in the image?',
#   'question_id': 131075011},
#  {'image_id': 131075,
#   'question': 'Is it a monitor or a screen projection?',
#   'question_id': 131075012},
#  {'image_id': 131075,
#   'question': 'What is on the TV screen?',
#   'question_id': 131075013},
#  {'image_id': 131075,
#   'question': 'What is the title of the presentation in the picture?',
#   'question_id': 131075014},
#  {'image_id': 137045,
#   'question': 'What color is the bear?',
#   'question_id': 137045000},
#  {'image_id': 137045,
#   'question': 'Is the animal a mammal?',
#   'question_id': 137045001},
#  {'image_id': 137045, 'question': 'What is this?', 'question_id': 137045002},
#  {'image_id': 131093,
#   'question': 'Are there rocks in the picture?',
#   'question_id': 131093000},
#  {'image_id': 131093,
#   'question': 'Has the sheep recently been shaved?',
#   'question_id': 131093001},
#  {'image_id': 131093,
#   'question': 'How many sheeps are this?',
#   'question_id': 131093002},
#  {'image_id': 131093,
#   'question': 'Are there three sheep?',
#   'question_id': 131093003},
#  {'image_id': 524311,
#   'question': 'What is the man playing?',
#   'question_id': 524311000},
#  {'image_id': 524311,
#   'question': 'Is the man having a good time?',
#   'question_id': 524311001},
#  {'image_id': 524311,
#   'question': 'What does the man have on his face?',
#   'question_id': 524311002},
#  {'image_id': 25,
#   'question': 'What is in front of the giraffes?',
#   'question_id': 25000},
#  {'image_id': 25,
#   'question': 'What do these giraffes have in common?',
#   'question_id': 25001},
#  {'image_id': 25,
#   'question': 'Could this photo be from a zoo?',
#   'question_id': 25002},
#  {'image_id': 25, 'question': 'Are the animals eating?', 'question_id': 25003},
#  {'image_id': 25, 'question': 'Where is the giraffe?', 'question_id': 25004},
#  {'image_id': 25, 'question': 'Is there a zebra?', 'question_id': 25005},
#  {'image_id': 25,
#   'question': 'What is the giraffe standing behind?',
#   'question_id': 25006},
#  {'image_id': 25,
#   'question': 'Is the giraffe eating the tree?',
#   'question_id': 25007},
#  {'image_id': 25,
#   'question': 'Are both giraffes standing?',
#   'question_id': 25008},
#  {'image_id': 25, 'question': 'Are they at a zoo?', 'question_id': 25009},
#  {'image_id': 25,
#   'question': 'What is on the ground next to the giraffe on the right?',
#   'question_id': 25010},
#  {'image_id': 25,
#   'question': 'Are some of the trees dead?',
#   'question_id': 25011},
#  {'image_id': 25,
#   'question': 'Are any of the animals eating?',
#   'question_id': 25012},
#  {'image_id': 25,
#   'question': 'Is the giraffe in the shade?',
#   'question_id': 25013},
#  {'image_id': 25,
#   'question': 'Are these giraffes living free range?',
#   'question_id': 25014},
#  {'image_id': 25,
#   'question': 'How many giraffes are there?',
#   'question_id': 25015},
#  {'image_id': 25,
#   'question': 'Is there a rock near the giraffe?',
#   'question_id': 25016},
#  {'image_id': 25,
#   'question': 'How many animals are in this photo?',
#   'question_id': 25017},
#  {'image_id': 524314,
#   'question': 'Why is the man on the street?',
#   'question_id': 524314000},
#  {'image_id': 524314,
#   'question': 'How is the man sitting?',
#   'question_id': 524314001},
#  {'image_id': 524314,
#   'question': 'What does the word in the upper-left corner, behind the window, translate to in English?',
#   'question_id': 524314002},
#  {'image_id': 262171,
#   'question': 'How many people are on the boat?',
#   'question_id': 262171000},
#  {'image_id': 262171,
#   'question': 'What color are the leaves?',
#   'question_id': 262171001},
#  {'image_id': 262171,
#   'question': 'What type of watercraft is that?',
#   'question_id': 262171002},
#  {'image_id': 262172,
#   'question': 'Where are the two blue coolers?',
#   'question_id': 262172000},
#  {'image_id': 262172,
#   'question': 'What kind of room is this?',
#   'question_id': 262172001},
#  {'image_id': 262172,
#   'question': 'Are they moving?',
#   'question_id': 262172002},
#  {'image_id': 131101,
#   'question': 'What color is the umbrella?',
#   'question_id': 131101000},
#  {'image_id': 131101,
#   'question': 'Is this man angry?',
#   'question_id': 131101001},
#  {'image_id': 131101,
#   'question': 'Which hand holds the umbrella?',
#   'question_id': 131101002},
#  {'image_id': 30,
#   'question': 'Are there flowers in the vase?',
#   'question_id': 30000},
#  {'image_id': 30,
#   'question': 'What is the vase sitting on?',
#   'question_id': 30001},
#  {'image_id': 30,
#   'question': 'Is the sun to the right or left of this flower?',
#   'question_id': 30002},
#  {'image_id': 30, 'question': 'Are the flowers open?', 'question_id': 30003},
#  {'image_id': 30, 'question': 'What color is the vase?', 'question_id': 30004},
#  {'image_id': 30,
#   'question': 'Are all the flowers white?',
#   'question_id': 30005},
#  {'image_id': 524320,
#   'question': 'Is the man standing on both foot?',
#   'question_id': 524320000},
#  {'image_id': 524320,
#   'question': 'Was this picture likely taken recently?',
#   'question_id': 524320001},
#  {'image_id': 524320,
#   'question': "Do the gentleman's socks match his shoes and belt?",
#   'question_id': 524320002},
#  {'image_id': 240304,
#   'question': 'What is the zebra eating?',
#   'question_id': 240304000},
#  {'image_id': 240304,
#   'question': 'Are the zebras facing the same direction?',
#   'question_id': 240304001},
#  {'image_id': 240304,
#   'question': 'What is the tree covered with?',
#   'question_id': 240304002},
#  {'image_id': 34, 'question': 'Is this a horse?', 'question_id': 34000},
#  {'image_id': 34,
#   'question': 'What is the animal eating?',
#   'question_id': 34001},
#  {'image_id': 34, 'question': 'How old is animal?', 'question_id': 34002},
#  {'image_id': 393251,
#   'question': "Are they drinking wine at the child's party?",
#   'question_id': 393251000},
#  {'image_id': 393251,
#   'question': 'Is the man wearing glasses?',
#   'question_id': 393251001},
#  {'image_id': 393251,
#   'question': 'What is the man holding?',
#   'question_id': 393251002},
#  {'image_id': 393251,
#   'question': 'What is the man cutting?',
#   'question_id': 393251003},
#  {'image_id': 262180,
#   'question': 'What is the fruit?',
#   'question_id': 262180000},
#  {'image_id': 262180,
#   'question': 'Is this a good dessert?',
#   'question_id': 262180001},
#  {'image_id': 262180,
#   'question': 'What is the name of the type of person that would make this food?',
#   'question_id': 262180002},
#  {'image_id': 262180,
#   'question': 'What type of ice cream is on the plate?',
#   'question_id': 262180003},
#  {'image_id': 524325,
#   'question': 'How many people are wearing shorts in the forefront of this photo?',
#   'question_id': 524325000},
#  {'image_id': 524325,
#   'question': 'Is this an indoor or outdoor photo?',
#   'question_id': 524325001},
#  {'image_id': 524325,
#   'question': 'Are those kites in the air?',
#   'question_id': 524325002},
#  {'image_id': 43697,
#   'question': 'Is this a hot dog?',
#   'question_id': 43697000},
#  {'image_id': 43697,
#   'question': 'What color is the napkin?',
#   'question_id': 43697001},
#  {'image_id': 43697,
#   'question': 'Is there ketchup on the hot dog?',
#   'question_id': 43697002},
#  {'image_id': 43697,
#   'question': 'Has this hot dog been grilled?',
#   'question_id': 43697003},
#  {'image_id': 43697,
#   'question': 'Have you tried a hot dog like this before?',
#   'question_id': 43697004},
#  {'image_id': 43697,
#   'question': "What's missing from this hot dog?",
#   'question_id': 43697005},
#  {'image_id': 43697,
#   'question': 'What is the hog dog sitting on?',
#   'question_id': 43697006},
#  {'image_id': 262184,
#   'question': 'Is this a toy-sized truck?',
#   'question_id': 262184000},
#  {'image_id': 262184,
#   'question': 'What is the sky full of?',
#   'question_id': 262184001},
#  {'image_id': 262184,
#   'question': 'Where are the trucks?',
#   'question_id': 262184002},
#  {'image_id': 131113,
#   'question': 'What is the color of the carpet?',
#   'question_id': 131113000},
#  {'image_id': 131113,
#   'question': 'Is there a carpet on the floor?',
#   'question_id': 131113001},
#  {'image_id': 131113,
#   'question': 'What color is the refrigerator?',
#   'question_id': 131113002},
#  {'image_id': 131113,
#   'question': 'What is this device?',
#   'question_id': 131113003},
#  {'image_id': 262187,
#   'question': 'Is this plane landing?',
#   'question_id': 262187000},
#  {'image_id': 262187,
#   'question': 'What color is the plane?',
#   'question_id': 262187001},
#  {'image_id': 262187,
#   'question': 'What shape are the windows on the side of the plane?',
#   'question_id': 262187002},
#  {'image_id': 262187,
#   'question': 'Is the plane taking off?',
#   'question_id': 262187003},
#  {'image_id': 131118,
#   'question': 'Are these airliners?',
#   'question_id': 131118000},
#  {'image_id': 131118,
#   'question': 'How many planes are in the picture?',
#   'question_id': 131118001},
#  {'image_id': 131118,
#   'question': 'Are this cargo planes?',
#   'question_id': 131118002},
#  {'image_id': 262191,
#   'question': 'Is this bear a normal size?',
#   'question_id': 262191000},
#  {'image_id': 262191,
#   'question': 'What is the website on the sign?',
#   'question_id': 262191001},
#  {'image_id': 262191,
#   'question': 'What is the bear called?',
#   'question_id': 262191002},
#  {'image_id': 49,
#   'question': 'Is there a flower arrangement on the lawn?',
#   'question_id': 49000},
#  {'image_id': 49,
#   'question': 'What color horse is closer to the camera?',
#   'question_id': 49001},
#  {'image_id': 49, 'question': 'Are they playing polo?', 'question_id': 49002},
#  {'image_id': 524338,
#   'question': 'How many trees are in this photo?',
#   'question_id': 524338000},
#  {'image_id': 524338,
#   'question': 'What type of tree is the man standing next to?',
#   'question_id': 524338001},
#  {'image_id': 524338,
#   'question': 'Is this man reading a cell phone screen?',
#   'question_id': 524338002},
#  {'image_id': 213863,
#   'question': 'What pattern is on the pants?',
#   'question_id': 213863000},
#  {'image_id': 213863,
#   'question': 'What sport is this person playing?',
#   'question_id': 213863001},
#  {'image_id': 213863,
#   'question': 'What is the position of the player behind the batter called?',
#   'question_id': 213863002},
#  {'image_id': 393268,
#   'question': "What color is the girl's shirt?",
#   'question_id': 393268000},
#  {'image_id': 393268,
#   'question': 'What are they drinking?',
#   'question_id': 393268001},
#  {'image_id': 393268,
#   'question': 'What brand of beer is visible?',
#   'question_id': 393268002},
#  {'image_id': 131126,
#   'question': 'Where is Brooklyn Avenue?',
#   'question_id': 131126000},
#  {'image_id': 131126,
#   'question': 'Which direction is Brooklyn Ave?',
#   'question_id': 131126001},
#  {'image_id': 131126,
#   'question': 'Is there a stop sign in the picture?',
#   'question_id': 131126002},
#  {'image_id': 131127,
#   'question': "What logo is on the man's shirt?",
#   'question_id': 131127000},
#  {'image_id': 131127,
#   'question': 'Is the man unhappy?',
#   'question_id': 131127001},
#  {'image_id': 131127,
#   'question': 'Are the men going to share the bananas?',
#   'question_id': 131127002},
#  {'image_id': 131128,
#   'question': 'What color are the flowers?',
#   'question_id': 131128000},
#  {'image_id': 131128,
#   'question': 'What colors are the flowers?',
#   'question_id': 131128001},
#  {'image_id': 131128,
#   'question': 'How many flowers are painted on the vase?',
#   'question_id': 131128002},
#  {'image_id': 131128,
#   'question': 'Do the painted flowers match the real ones?',
#   'question_id': 131128003},
#  {'image_id': 262201,
#   'question': 'Where is the bird?',
#   'question_id': 262201000},
#  {'image_id': 262201,
#   'question': 'Will the birds go into the water?',
#   'question_id': 262201001},
#  {'image_id': 262201,
#   'question': 'What direction is the bird looking?',
#   'question_id': 262201002},
#  {'image_id': 262201,
#   'question': 'Is this bird afraid of the ledge?',
#   'question_id': 262201003},
#  {'image_id': 370986,
#   'question': 'What time of day is it?',
#   'question_id': 370986000},
#  {'image_id': 370986,
#   'question': 'How many elephants are in the water?',
#   'question_id': 370986001},
#  {'image_id': 370986,
#   'question': 'How many tails can you see in this picture?',
#   'question_id': 370986002},
#  {'image_id': 262204,
#   'question': 'How many tusks are visible?',
#   'question_id': 262204000},
#  {'image_id': 262204,
#   'question': 'What is this animal?',
#   'question_id': 262204001},
#  {'image_id': 262204,
#   'question': 'What color is the animal?',
#   'question_id': 262204002},
#  {'image_id': 131133,
#   'question': 'What color is the plane?',
#   'question_id': 131133000},
#  {'image_id': 131133,
#   'question': 'What type of plane is this?',
#   'question_id': 131133001},
#  {'image_id': 131133,
#   'question': 'Are the mountains high?',
#   'question_id': 131133002},
#  {'image_id': 262207,
#   'question': 'What color are the seats?',
#   'question_id': 262207000},
#  {'image_id': 262207,
#   'question': 'Is there a person standing in front of the television?',
#   'question_id': 262207001},
#  {'image_id': 262207,
#   'question': 'Where is the mirror?',
#   'question_id': 262207002},
#  {'image_id': 262207,
#   'question': 'Is there enough room under the armchairs for a cat to hide?',
#   'question_id': 262207003},
#  {'image_id': 64, 'question': 'Who made the cock?', 'question_id': 64000},
#  {'image_id': 64,
#   'question': 'Are there numbers on the clock face?',
#   'question_id': 64001},
#  {'image_id': 64,
#   'question': 'Is there a big tree behind the clock?',
#   'question_id': 64002},
#  {'image_id': 64, 'question': 'What is in the picture?', 'question_id': 64003},
#  {'image_id': 64,
#   'question': 'What time is the clock showing?',
#   'question_id': 64004},
#  {'image_id': 458763,
#   'question': 'What are the vases sitting on?',
#   'question_id': 458763000},
#  {'image_id': 458763,
#   'question': 'How many trees on the table?',
#   'question_id': 458763001},
#  {'image_id': 458763,
#   'question': 'How many horns are in the picture?',
#   'question_id': 458763002},
#  {'image_id': 458763,
#   'question': 'What color is the middle vase?',
#   'question_id': 458763003},
#  {'image_id': 458763,
#   'question': 'What is the table made of?',
#   'question_id': 458763004},
#  {'image_id': 458763,
#   'question': 'What kind of trees are on the table?',
#   'question_id': 458763005},
#  {'image_id': 458763,
#   'question': 'Is this a wedding?',
#   'question_id': 458763006},
#  {'image_id': 567990,
#   'question': 'What is the green stuff on this pizza?',
#   'question_id': 567990000},
#  {'image_id': 567990,
#   'question': 'Does the crust look burnt?',
#   'question_id': 567990001},
#  {'image_id': 567990,
#   'question': 'Is it thick or thin crust?',
#   'question_id': 567990002},
#  {'image_id': 567990,
#   'question': 'Does this pizza have a deep dish crust?',
#   'question_id': 567990003},
#  {'image_id': 393286,
#   'question': 'Is the banana freshly peeled?',
#   'question_id': 393286000},
#  {'image_id': 393286,
#   'question': 'Is the banana closed?',
#   'question_id': 393286001},
#  {'image_id': 393286,
#   'question': 'What is the orange thing?',
#   'question_id': 393286002},
#  {'image_id': 71,
#   'question': 'Does this photo show train tracks?',
#   'question_id': 71000},
#  {'image_id': 71, 'question': 'Does this train work?', 'question_id': 71001},
#  {'image_id': 71,
#   'question': 'Is this train headed towards or from the orange building?',
#   'question_id': 71002},
#  {'image_id': 72,
#   'question': 'How many Giraffes are in this image?',
#   'question_id': 72000},
#  {'image_id': 72,
#   'question': 'What is the giraffe eating?',
#   'question_id': 72001},
#  {'image_id': 72,
#   'question': 'Are the giraffes under the trees?',
#   'question_id': 72002},
#  {'image_id': 393228,
#   'question': 'Are there 3 elephants?',
#   'question_id': 393228000},
#  {'image_id': 393228,
#   'question': 'Are all of the elephants full grown?',
#   'question_id': 393228001},
#  {'image_id': 393228,
#   'question': 'Are the elephants in the jungle?',
#   'question_id': 393228002},
#  {'image_id': 393290,
#   'question': "What is on the woman's neck?",
#   'question_id': 393290000},
#  {'image_id': 393290,
#   'question': 'Is the woman eating the pizza?',
#   'question_id': 393290001},
#  {'image_id': 393290,
#   'question': 'How many stairs are there?',
#   'question_id': 393290002},
#  {'image_id': 393291,
#   'question': 'Where is the sink located?',
#   'question_id': 393291000},
#  {'image_id': 393291,
#   'question': 'Where is the soap?',
#   'question_id': 393291001},
#  {'image_id': 393291,
#   'question': 'What color is the window frame?',
#   'question_id': 393291002},
#  {'image_id': 393291,
#   'question': 'What item is folded up and sitting on the edge of the shower stall?',
#   'question_id': 393291003},
#  {'image_id': 393291,
#   'question': 'What pattern is on the shower curtain?',
#   'question_id': 393291004},
#  {'image_id': 393291,
#   'question': 'What are the colors of the countertop?',
#   'question_id': 393291005},
#  {'image_id': 393291,
#   'question': 'Are there any reflections in this picture?',
#   'question_id': 393291006},
#  {'image_id': 393291,
#   'question': 'How many windows are there?',
#   'question_id': 393291007},
#  {'image_id': 393292,
#   'question': 'Is the water on?',
#   'question_id': 393292000},
#  {'image_id': 393292,
#   'question': 'Is this photo outdoors?',
#   'question_id': 393292001},
#  {'image_id': 393292,
#   'question': 'How many birds are in the sink?',
#   'question_id': 393292002},
#  {'image_id': 262221,
#   'question': 'What is the person on the right called?',
#   'question_id': 262221000},
#  {'image_id': 262221,
#   'question': "Whose logo is on the official's chair?",
#   'question_id': 262221001},
#  {'image_id': 262221,
#   'question': 'How many tennis players are in the photo?',
#   'question_id': 262221002},
#  {'image_id': 78,
#   'question': 'Are the clock and owl made in the same artistic fashion?',
#   'question_id': 78000},
#  {'image_id': 78, 'question': 'Is that owl a candle?', 'question_id': 78001},
#  {'image_id': 78,
#   'question': 'What time does the clock say?',
#   'question_id': 78002},
#  {'image_id': 81,
#   'question': 'Does this planes tail have 4 colors?',
#   'question_id': 81000},
#  {'image_id': 81, 'question': 'Is this plane landing?', 'question_id': 81001},
#  {'image_id': 81,
#   'question': 'Is this plane taking off?',
#   'question_id': 81002},
#  {'image_id': 81,
#   'question': 'What is the last letter over the plane?',
#   'question_id': 81003},
#  {'image_id': 81, 'question': 'Are these wings strong?', 'question_id': 81004},
#  {'image_id': 86, 'question': 'Is that a bicycle?', 'question_id': 86000},
#  {'image_id': 86,
#   'question': 'What is the number on the mailbox?',
#   'question_id': 86001},
#  {'image_id': 86,
#   'question': 'What is this person wearing on head?',
#   'question_id': 86002},
#  {'image_id': 524375,
#   'question': 'Is this a cow farm?',
#   'question_id': 524375000},
#  {'image_id': 524375,
#   'question': 'What are the animals doing?',
#   'question_id': 524375001},
#  {'image_id': 524375,
#   'question': 'What breed of livestock is shown?',
#   'question_id': 524375002},
#  {'image_id': 524375,
#   'question': 'How many black sheep are there?',
#   'question_id': 524375003},
#  {'image_id': 524375,
#   'question': 'What game would you play when you saw this as a child?',
#   'question_id': 524375004},
#  {'image_id': 524375,
#   'question': 'Where is the human?',
#   'question_id': 524375005},
#  {'image_id': 524375,
#   'question': 'Is this a prairie?',
#   'question_id': 524375006},
#  {'image_id': 524375,
#   'question': 'Is there a village in the background?',
#   'question_id': 524375007},
#  {'image_id': 131160,
#   'question': 'What color is the sign?',
#   'question_id': 131160000},
#  {'image_id': 131160,
#   'question': 'Would you be able to find a mosque in this city?',
#   'question_id': 131160001},
#  {'image_id': 131160,
#   'question': 'What language is the sign written in?',
#   'question_id': 131160002},
#  {'image_id': 524377,
#   'question': 'How has the cheese been prepared?',
#   'question_id': 524377000},
#  {'image_id': 524377,
#   'question': 'Is there ketchup?',
#   'question_id': 524377001},
#  {'image_id': 524377,
#   'question': 'How many lunches is this?',
#   'question_id': 524377002},
#  {'image_id': 524377,
#   'question': 'Is the hotdog well seasoned?',
#   'question_id': 524377003},
#  {'image_id': 524377,
#   'question': 'What kind of food is shown?',
#   'question_id': 524377004},
#  {'image_id': 524377,
#   'question': 'What is the cutting board used for in this scene?',
#   'question_id': 524377005},
#  {'image_id': 524377,
#   'question': 'Of what meal is this kind of food typical?',
#   'question_id': 524377006},
#  {'image_id': 524377,
#   'question': 'Is this a healthy meal?',
#   'question_id': 524377007},
#  {'image_id': 524377,
#   'question': 'What kind of sauce is in the largest ramekin?',
#   'question_id': 524377008},
#  {'image_id': 524377,
#   'question': 'What type of food is shown?',
#   'question_id': 524377009},
#  {'image_id': 524377,
#   'question': 'What is the topping on the hot dog?',
#   'question_id': 524377010},
#  {'image_id': 524377,
#   'question': 'What topping is on the hot dog?',
#   'question_id': 524377011},
#  {'image_id': 524377,
#   'question': 'What is in the small container?',
#   'question_id': 524377012},
#  {'image_id': 524377,
#   'question': 'What are the components of this dish?',
#   'question_id': 524377013},
#  {'image_id': 524377,
#   'question': 'What kind of toppings are on the hot dogs?',
#   'question_id': 524377014},
#  {'image_id': 524377,
#   'question': 'Is there a spoon in this photo?',
#   'question_id': 524377015},
#  {'image_id': 524377,
#   'question': 'Is this breakfast?',
#   'question_id': 524377016},
#  {'image_id': 524377,
#   'question': 'How delicious does this look?',
#   'question_id': 524377017},
#  {'image_id': 524377,
#   'question': 'What two vegetables are in the white bowl?',
#   'question_id': 524377018},
#  {'image_id': 524377,
#   'question': 'How many hot dogs are shown?',
#   'question_id': 524377019},
#  {'image_id': 524377,
#   'question': 'What type of filling is in the dish on the bottom left?',
#   'question_id': 524377020},
#  {'image_id': 524377,
#   'question': 'What color is the tray?',
#   'question_id': 524377021},
#  {'image_id': 524377,
#   'question': 'How many pickle spears are there?',
#   'question_id': 524377022},
#  {'image_id': 524377,
#   'question': 'What is the yellow stuff in a bowl?',
#   'question_id': 524377023},
#  {'image_id': 524377,
#   'question': 'How many people are eating this hotdog?',
#   'question_id': 524377024},
#  {'image_id': 524377,
#   'question': 'Is there a drink in this picture?',
#   'question_id': 524377025},
#  {'image_id': 524377,
#   'question': 'What is the hot dog sitting on top of?',
#   'question_id': 524377026},
#  {'image_id': 524377,
#   'question': 'How many sauces are there?',
#   'question_id': 524377027},
#  {'image_id': 524377,
#   'question': 'What are the orange things?',
#   'question_id': 524377028},
#  {'image_id': 524377,
#   'question': 'Are the carrots diced or cut long ways?',
#   'question_id': 524377029},
#  {'image_id': 524377,
#   'question': 'Do these hot dogs look like they taste good?',
#   'question_id': 524377030},
#  {'image_id': 524377,
#   'question': 'Are those tomatoes on the sandwich?',
#   'question_id': 524377031},
#  {'image_id': 524377,
#   'question': 'What is in the cup?',
#   'question_id': 524377032},
#  {'image_id': 524377,
#   'question': 'What is the orange root called?',
#   'question_id': 524377033},
#  {'image_id': 524377,
#   'question': 'What is the blackened meat on the bread?',
#   'question_id': 524377034},
#  {'image_id': 524377,
#   'question': 'What kind of meat is this?',
#   'question_id': 524377035},
#  {'image_id': 524377,
#   'question': 'What is on the sandwich?',
#   'question_id': 524377036},
#  {'image_id': 524377,
#   'question': 'Are the fries plain?',
#   'question_id': 524377037},
#  {'image_id': 524377,
#   'question': 'Does this breakfast dish primarily carbohydrates?',
#   'question_id': 524377038},
#  {'image_id': 524377,
#   'question': 'Has someone started eating?',
#   'question_id': 524377039},
#  {'image_id': 524377,
#   'question': 'What animal is on the plate?',
#   'question_id': 524377040},
#  {'image_id': 524377,
#   'question': 'Would this be good for dessert?',
#   'question_id': 524377041},
#  {'image_id': 524377,
#   'question': 'Is there a butter plate on the table?',
#   'question_id': 524377042},
#  {'image_id': 524377,
#   'question': 'Does this have lettuce?',
#   'question_id': 524377043},
#  {'image_id': 524377,
#   'question': 'Does the food look good?',
#   'question_id': 524377044},
#  {'image_id': 524377, 'question': 'Is this meat?', 'question_id': 524377045},
#  {'image_id': 524377,
#   'question': 'What is on the hotdog?',
#   'question_id': 524377046},
#  {'image_id': 524377,
#   'question': 'What two vegetables can be seen on the pizza?',
#   'question_id': 524377047},
#  {'image_id': 524377,
#   'question': 'Would this typically be eaten for breakfast?',
#   'question_id': 524377048},
#  {'image_id': 524377,
#   'question': 'Is that bacon from a delicatessen?',
#   'question_id': 524377049},
#  {'image_id': 524377,
#   'question': 'What condiment is on the potatoes?',
#   'question_id': 524377050},
#  {'image_id': 524377,
#   'question': 'How many kinds of meat products are here?',
#   'question_id': 524377051},
#  {'image_id': 524377,
#   'question': 'What sauces are shown?',
#   'question_id': 524377052},
#  {'image_id': 524377,
#   'question': 'What kind of potato are the fries?',
#   'question_id': 524377053},
#  {'image_id': 524377,
#   'question': 'What is mainly featured?',
#   'question_id': 524377054},
#  {'image_id': 393306,
#   'question': 'Is the man wearing formal clothes?',
#   'question_id': 393306000},
#  {'image_id': 393306,
#   'question': 'What kind of plants are these?',
#   'question_id': 393306001},
#  {'image_id': 393306,
#   'question': 'What is the pattern on the vase?',
#   'question_id': 393306002},
#  {'image_id': 393306,
#   'question': 'Which hand is the man holding up?',
#   'question_id': 393306003},
#  {'image_id': 262159,
#   'question': 'Is there a deodorant on the sink?',
#   'question_id': 262159000},
#  {'image_id': 262159,
#   'question': 'Is there a full roll of toilet paper in the bathroom?',
#   'question_id': 262159001},
#  {'image_id': 262159,
#   'question': 'How many rolls of toilet paper are on the toilet tank?',
#   'question_id': 262159002},
#  {'image_id': 262159,
#   'question': 'Would someone be able to watch you change from the outside?',
#   'question_id': 262159003},
#  {'image_id': 262159,
#   'question': 'What color is the bathroom?',
#   'question_id': 262159004},
#  {'image_id': 262159,
#   'question': 'Does the shower have a glass door?',
#   'question_id': 262159005},
#  {'image_id': 262159,
#   'question': 'What is the primary color of the bathroom?',
#   'question_id': 262159006},
#  {'image_id': 262159,
#   'question': 'What color is the wall?',
#   'question_id': 262159007},
#  {'image_id': 262159,
#   'question': 'Is the towel rack silver?',
#   'question_id': 262159008},
#  {'image_id': 262159,
#   'question': 'Is there a shower curtain?',
#   'question_id': 262159009},
#  {'image_id': 262159,
#   'question': 'What color are the bathroom walls?',
#   'question_id': 262159010},
#  {'image_id': 262159,
#   'question': 'Where is the light coming from?',
#   'question_id': 262159011},
#  {'image_id': 262159,
#   'question': 'Is the toilet lid down?',
#   'question_id': 262159012},
#  {'image_id': 92,
#   'question': 'How many layers are in this cake?',
#   'question_id': 92000},
#  {'image_id': 92,
#   'question': 'Does this cake look like it chocolate?',
#   'question_id': 92001},
#  {'image_id': 92,
#   'question': 'How many people can eat this cake?',
#   'question_id': 92002},
#  {'image_id': 94,
#   'question': 'What is printed on the orange sign?',
#   'question_id': 94000},
#  {'image_id': 94,
#   'question': 'What is the name of the hotel?',
#   'question_id': 94001},
#  {'image_id': 94,
#   'question': 'How many vehicles are shown?',
#   'question_id': 94002},
#  {'image_id': 94,
#   'question': 'What mode of transportation is pictured?',
#   'question_id': 94003},
#  {'image_id': 94, 'question': 'Is this a small town?', 'question_id': 94004},
#  {'image_id': 393311,
#   'question': 'Will these planes be used to transport people?',
#   'question_id': 393311000},
#  {'image_id': 393311,
#   'question': 'What airline is this?',
#   'question_id': 393311001},
#  {'image_id': 393311,
#   'question': "The plane's stand resembles what letter?",
#   'question_id': 393311002},
#  {'image_id': 393311,
#   'question': 'What type of plane is this?',
#   'question_id': 393311003},
#  {'image_id': 393311,
#   'question': 'What is written on the picture?',
#   'question_id': 393311004},
#  {'image_id': 393311,
#   'question': 'What shipping company is represented in the scene?',
#   'question_id': 393311005},
#  {'image_id': 393311,
#   'question': 'What airline is this plane from?',
#   'question_id': 393311006},
#  {'image_id': 393311,
#   'question': 'What kind of aircraft is this?',
#   'question_id': 393311007},
#  {'image_id': 393311,
#   'question': 'How does the man get down from the machine?',
#   'question_id': 393311008},
#  {'image_id': 524386,
#   'question': 'Is the room carpeted?',
#   'question_id': 524386000},
#  {'image_id': 524386,
#   'question': 'Where is the television?',
#   'question_id': 524386001},
#  {'image_id': 524386,
#   'question': 'Is there a fireplace?',
#   'question_id': 524386002},
#  {'image_id': 524386,
#   'question': 'Are stains on the floor?',
#   'question_id': 524386003},
#  {'image_id': 524386,
#   'question': 'How many lamps are there?',
#   'question_id': 524386004},
#  {'image_id': 524386,
#   'question': 'What is the picture of on wall?',
#   'question_id': 524386005},
#  {'image_id': 524386,
#   'question': 'What is on the carpet?',
#   'question_id': 524386006},
#  {'image_id': 524386,
#   'question': 'How many lamps are in the room?',
#   'question_id': 524386007},
#  {'image_id': 524386,
#   'question': 'Are these boys at home?',
#   'question_id': 524386008},
#  {'image_id': 524386,
#   'question': 'What kind of lamp is on the floor?',
#   'question_id': 524386009},
#  {'image_id': 524386,
#   'question': "Is this a 60's motif?",
#   'question_id': 524386010},
#  {'image_id': 524386,
#   'question': 'How many pictures on the wall?',
#   'question_id': 524386011},
#  {'image_id': 524386,
#   'question': 'Which floor lamp is not lit?',
#   'question_id': 524386012},
#  {'image_id': 524386,
#   'question': 'How many TVs are on?',
#   'question_id': 524386013},
#  {'image_id': 524386,
#   'question': 'What color is the sofa?',
#   'question_id': 524386014},
#  {'image_id': 524386,
#   'question': 'How many pictures are on the wall?',
#   'question_id': 524386015},
#  {'image_id': 131172,
#   'question': 'How many men in the picture are wearing sunglasses?',
#   'question_id': 131172000},
#  {'image_id': 131172,
#   'question': 'What kind of hat is the man with the girls wearing?',
#   'question_id': 131172001},
#  {'image_id': 131172,
#   'question': "What color is the man's shirt in the front of the photo?",
#   'question_id': 131172002},
#  {'image_id': 131172,
#   'question': 'What are the ladies doing?',
#   'question_id': 131172003},
#  {'image_id': 393317,
#   'question': 'Where is the street sign?',
#   'question_id': 393317000},
#  {'image_id': 393317,
#   'question': 'Where are the women walking?',
#   'question_id': 393317001},
#  {'image_id': 393317,
#   'question': 'Is the light green?',
#   'question_id': 393317002},
#  {'image_id': 393317,
#   'question': 'What is written on the street?',
#   'question_id': 393317003},
#  {'image_id': 393317, 'question': 'Is it raining?', 'question_id': 393317004},
#  {'image_id': 393317,
#   'question': 'Urban or suburban?',
#   'question_id': 393317005},
#  {'image_id': 393317,
#   'question': 'Where is the woman standing?',
#   'question_id': 393317006},
#  {'image_id': 393317,
#   'question': 'How many people can be seen?',
#   'question_id': 393317007},
#  {'image_id': 393317,
#   'question': 'What type of vehicle is on the left?',
#   'question_id': 393317008},
#  {'image_id': 393317,
#   'question': 'Is this woman crossing a street?',
#   'question_id': 393317009},
#  {'image_id': 393317,
#   'question': 'What color is the traffic signal?',
#   'question_id': 393317010},
#  {'image_id': 393317,
#   'question': 'What is being held green?',
#   'question_id': 393317011},
#  {'image_id': 393317,
#   'question': 'What time of day is it?',
#   'question_id': 393317012},
#  {'image_id': 393317,
#   'question': 'Is this in the United States?',
#   'question_id': 393317013},
#  {'image_id': 393317,
#   'question': 'How many green lights are there?',
#   'question_id': 393317014},
#  {'image_id': 131174,
#   'question': 'How many lights does the plane have?',
#   'question_id': 131174000},
#  {'image_id': 131174,
#   'question': 'How many planes are in this photo?',
#   'question_id': 131174001},
#  {'image_id': 131174,
#   'question': 'Is there anyone in the cockpit?',
#   'question_id': 131174002},
#  {'image_id': 546151,
#   'question': 'What country name is written as the highest word on the bus?',
#   'question_id': 546151000},
#  {'image_id': 546151,
#   'question': 'Is the bus stopped?',
#   'question_id': 546151001},
#  {'image_id': 546151,
#   'question': 'How many people are standing in this image?',
#   'question_id': 546151002},
#  {'image_id': 21826,
#   'question': 'What is the skier standing on?',
#   'question_id': 21826000},
#  {'image_id': 21826,
#   'question': 'How many poles is the person holding?',
#   'question_id': 21826001},
#  {'image_id': 21826,
#   'question': 'What is the person doing?',
#   'question_id': 21826002},
#  {'image_id': 109,
#   'question': 'Is this an ocean area?',
#   'question_id': 109000},
#  {'image_id': 109,
#   'question': 'How many bodies of water are in this scene?',
#   'question_id': 109001},
#  {'image_id': 109,
#   'question': 'How many light post is there?',
#   'question_id': 109002},
#  {'image_id': 109,
#   'question': 'Is the ground near the waterfront squishy?',
#   'question_id': 109003},
#  {'image_id': 109,
#   'question': 'What infrastructure would one drive on to go perpendicular to the water?',
#   'question_id': 109004},
#  {'image_id': 109, 'question': 'Is the water calm?', 'question_id': 109005},
#  {'image_id': 110,
#   'question': "What color is the woman's sweater?",
#   'question_id': 110000},
#  {'image_id': 110,
#   'question': 'Is this a cheese pizza?',
#   'question_id': 110001},
#  {'image_id': 110,
#   'question': 'What pizza topping is this?',
#   'question_id': 110002},
#  {'image_id': 305853,
#   'question': 'What is in the vase next to the flowers?',
#   'question_id': 305853000},
#  {'image_id': 305853,
#   'question': 'Is there more than one vase on the table?',
#   'question_id': 305853001},
#  {'image_id': 305853,
#   'question': 'Are these flowers real or silk?',
#   'question_id': 305853002},
#  {'image_id': 305853,
#   'question': "England's Queen mother and these blooms share what syllable?",
#   'question_id': 305853003},
#  {'image_id': 113,
#   'question': 'How many people are in the picture?',
#   'question_id': 113000},
#  {'image_id': 113,
#   'question': 'What color are the chairs?',
#   'question_id': 113001},
#  {'image_id': 113,
#   'question': 'What kind of celebration is this?',
#   'question_id': 113002},
#  {'image_id': 113,
#   'question': 'What emblem is on the cake?',
#   'question_id': 113003},
#  {'image_id': 113,
#   'question': 'Are they outside or in?',
#   'question_id': 113004},
#  {'image_id': 113, 'question': 'Is there a cake here?', 'question_id': 113005},
#  {'image_id': 113,
#   'question': 'Are there any pens on the table?',
#   'question_id': 113006},
#  {'image_id': 113,
#   'question': 'What are the initials on the cake?',
#   'question_id': 113007},
#  {'image_id': 262260,
#   'question': 'Why are the birds only appearing as black silhouettes?',
#   'question_id': 262260000},
#  {'image_id': 262260,
#   'question': 'How many pigeons are there?',
#   'question_id': 262260001},
#  {'image_id': 262260,
#   'question': 'Is this image tilted?',
#   'question_id': 262260002},
#  {'image_id': 262261,
#   'question': 'What utensil is in the pan?',
#   'question_id': 262261000},
#  {'image_id': 262261,
#   'question': 'What is the red vegetable in the clear dish?',
#   'question_id': 262261001},
#  {'image_id': 262261,
#   'question': 'Does this image contain a pie pan?',
#   'question_id': 262261002},
#  {'image_id': 131190,
#   'question': 'Is this a large house?',
#   'question_id': 131190000},
#  {'image_id': 131190,
#   'question': 'Is there a fountain in front of the building?',
#   'question_id': 131190001},
#  {'image_id': 131190,
#   'question': 'Is the sun shining?',
#   'question_id': 131190002},
#  {'image_id': 131190,
#   'question': 'What color is the building?',
#   'question_id': 131190003},
#  {'image_id': 131190,
#   'question': 'Is this a church?',
#   'question_id': 131190004},
#  {'image_id': 131190,
#   'question': 'What tree is on the left?',
#   'question_id': 131190005},
#  {'image_id': 131190,
#   'question': 'Are there clouds visible?',
#   'question_id': 131190006},
#  {'image_id': 131190,
#   'question': 'Is this a sunny day?',
#   'question_id': 131190007},
#  {'image_id': 131190,
#   'question': 'What is the material right around the clock?',
#   'question_id': 131190008},
#  {'image_id': 131190,
#   'question': 'What color are the flowers?',
#   'question_id': 131190009},
#  {'image_id': 131190,
#   'question': 'How many bells are there?',
#   'question_id': 131190010},
#  {'image_id': 131190,
#   'question': 'How tall is this building?',
#   'question_id': 131190011},
#  {'image_id': 131190,
#   'question': 'What materials are on the roof?',
#   'question_id': 131190012},
#  {'image_id': 131190,
#   'question': 'How many clock faces does this building have?',
#   'question_id': 131190013},
#  {'image_id': 131190,
#   'question': 'Are the hedges well-groomed?',
#   'question_id': 131190014},
#  {'image_id': 131190,
#   'question': 'Does the building in the back have an elevator?',
#   'question_id': 131190015},
#  {'image_id': 131190,
#   'question': 'What is in gold at the top of the building?',
#   'question_id': 131190016},
#  {'image_id': 131190,
#   'question': 'Do you a phone booth?',
#   'question_id': 131190017},
#  {'image_id': 131190,
#   'question': 'What color is the clock tower in this photo?',
#   'question_id': 131190018},
#  {'image_id': 131190,
#   'question': 'What are on both side of the building?',
#   'question_id': 131190019},
#  {'image_id': 131190,
#   'question': 'What is around the tree?',
#   'question_id': 131190020},
#  {'image_id': 131190,
#   'question': 'Are the buildings tall?',
#   'question_id': 131190021},
#  {'image_id': 131190,
#   'question': "How many flags are by the building's entrance?",
#   'question_id': 131190022},
#  {'image_id': 131190,
#   'question': 'Is the clock between two arches?',
#   'question_id': 131190023},
#  {'image_id': 131190,
#   'question': 'Are there any entrance gates at the bottom of the tower?',
#   'question_id': 131190024},
#  {'image_id': 131190,
#   'question': 'Is the building a high rise?',
#   'question_id': 131190025},
#  {'image_id': 131190,
#   'question': 'Is part of this tower made of wood?',
#   'question_id': 131190026},
#  {'image_id': 131190,
#   'question': 'Can the tree tell time?',
#   'question_id': 131190027},
#  {'image_id': 131190,
#   'question': 'How many windows are shown?',
#   'question_id': 131190028},
#  {'image_id': 131190,
#   'question': 'How many windows are pictured?',
#   'question_id': 131190029},
#  {'image_id': 131190,
#   'question': 'Is the emblem a sun face clock?',
#   'question_id': 131190030},
#  {'image_id': 131197,
#   'question': 'What is the woman doing in this photo?',
#   'question_id': 131197000},
#  {'image_id': 131197,
#   'question': 'What are the sheep standing on?',
#   'question_id': 131197001},
#  {'image_id': 131197,
#   'question': 'What is the woman feeding the animal?',
#   'question_id': 131197002},
#  {'image_id': 131197,
#   'question': 'How many sheep can you see?',
#   'question_id': 131197003},
#  {'image_id': 131197,
#   'question': "Is the ram's fleece dirty?",
#   'question_id': 131197004},
#  {'image_id': 127,
#   'question': 'Is there a travel guide on the table?',
#   'question_id': 127000},
#  {'image_id': 127,
#   'question': 'What color plate is this?',
#   'question_id': 127001},
#  {'image_id': 127,
#   'question': 'What type of silverware is on the plates?',
#   'question_id': 127002},
#  {'image_id': 262273,
#   'question': 'What color are the skis?',
#   'question_id': 262273000},
#  {'image_id': 262273, 'question': 'Is there snow?', 'question_id': 262273001},
#  {'image_id': 262273,
#   'question': 'What is the man holding in his left hand?',
#   'question_id': 262273002},
#  {'image_id': 262273,
#   'question': 'What is the color of the zipper?',
#   'question_id': 262273003},
#  {'image_id': 262273,
#   'question': 'Are the boots a solid color or patterned?',
#   'question_id': 262273004},
#  {'image_id': 262273,
#   'question': 'How many people are there?',
#   'question_id': 262273005},
#  {'image_id': 262273, 'question': 'Is it summer?', 'question_id': 262273006},
#  {'image_id': 262273,
#   'question': "What color is the man's hat?",
#   'question_id': 262273007},
#  {'image_id': 262273,
#   'question': 'How many people are in the image?',
#   'question_id': 262273008},
#  {'image_id': 524420,
#   'question': "What color is the woman's shorts?",
#   'question_id': 524420000},
#  {'image_id': 524420,
#   'question': 'Is the picture in color?',
#   'question_id': 524420001},
#  {'image_id': 524420,
#   'question': 'Is there a dog in the photo?',
#   'question_id': 524420002},
#  {'image_id': 524420,
#   'question': 'Is the dog on a leash?',
#   'question_id': 524420003},
#  {'image_id': 524420,
#   'question': 'What are the people doing in the street?',
#   'question_id': 524420004},
#  {'image_id': 436929,
#   'question': 'What is floating near the bird?',
#   'question_id': 436929000},
#  {'image_id': 436929,
#   'question': 'Are all of the birds in flight?',
#   'question_id': 436929001},
#  {'image_id': 436929,
#   'question': 'How many birds are there?',
#   'question_id': 436929002},
#  {'image_id': 436929,
#   'question': 'Are there three birds in the picture?',
#   'question_id': 436929003},
# ...
#   'question_id': 131339002},
#  {'image_id': 131339,
#   'question': 'Is this man riding a surfboard?',
#   'question_id': 131339003},
#  {'image_id': 131339,
#   'question': 'Is he wearing the right type of suit?',
#   'question_id': 131339004},
#  {'image_id': 131339,
#   'question': 'Is the man riding a white board?',
#   'question_id': 131339005},
#  {'image_id': 131339,
#   'question': 'How many people are surfing?',
#   'question_id': 131339006},
#  {'image_id': 131339,
#   'question': 'Is the woman surfing?',
#   'question_id': 131339007},
#  {'image_id': 131339,
#   'question': 'What kind of suit is he wearing?',
#   'question_id': 131339008},
#  {'image_id': 524557,
#   'question': 'What sport are they playing?',
#   'question_id': 524557000},
#  {'image_id': 524557,
#   'question': 'Color is the goaltenders shirt?',
#   'question_id': 524557001},
#  {'image_id': 524557,
#   'question': 'Where is number 8?',
#   'question_id': 524557002},
#  {'image_id': 524557,
#   'question': 'How many kids are wearing black and white?',
#   'question_id': 524557003},
#  {'image_id': 524557,
#   'question': 'Is the boy in the middle being attacked?',
#   'question_id': 524557004},
#  {'image_id': 524557,
#   'question': 'Does the boy have his head stuck in the net?',
#   'question_id': 524557005},
#  {'image_id': 131342,
#   'question': 'How many men are wearing hats?',
#   'question_id': 131342000},
#  {'image_id': 131342,
#   'question': 'Does the guy on the right look happy?',
#   'question_id': 131342001},
#  {'image_id': 131342,
#   'question': 'Are they coworkers or best friends?',
#   'question_id': 131342002},
#  {'image_id': 131342,
#   'question': 'What is in the glass in the lower right?',
#   'question_id': 131342003},
#  {'image_id': 131342,
#   'question': 'The wall is made out of?',
#   'question_id': 131342004},
#  {'image_id': 262415,
#   'question': 'What does the sign in the background say?',
#   'question_id': 262415000},
#  {'image_id': 262415,
#   'question': 'What color is the bus in the mirror?',
#   'question_id': 262415001},
#  {'image_id': 262415,
#   'question': 'What is behind the mirror?',
#   'question_id': 262415002},
#  {'image_id': 262415,
#   'question': 'What kind of passenger does the bus carry?',
#   'question_id': 262415003},
#  {'image_id': 393488,
#   'question': 'How healthy does this meal look?',
#   'question_id': 393488000},
#  {'image_id': 393488,
#   'question': 'Are there multiple vegetables on the plate?',
#   'question_id': 393488001},
#  {'image_id': 393488,
#   'question': 'What meat is used in the main dish?',
#   'question_id': 393488002},
#  {'image_id': 393488,
#   'question': 'Is there meat on the plate?',
#   'question_id': 393488003},
#  {'image_id': 393489,
#   'question': 'What is the man reaching for?',
#   'question_id': 393489000},
#  {'image_id': 393489,
#   'question': 'Is this a brand new phone?',
#   'question_id': 393489001},
#  {'image_id': 393489,
#   'question': 'What kind of id is that?',
#   'question_id': 393489002},
#  {'image_id': 393489,
#   'question': 'What color is the phone?',
#   'question_id': 393489003},
#  {'image_id': 393489,
#   'question': 'Does this phone fold closed?',
#   'question_id': 393489004},
#  {'image_id': 393489,
#   'question': 'What language is the text on the sign?',
#   'question_id': 393489005},
#  {'image_id': 393489,
#   'question': 'How many holes are on the phone case?',
#   'question_id': 393489006},
#  {'image_id': 393489,
#   'question': 'What is the man holding?',
#   'question_id': 393489007},
#  {'image_id': 393489,
#   'question': 'What does this phone case look like?',
#   'question_id': 393489008},
#  {'image_id': 393489,
#   'question': 'What is the brand of the phone?',
#   'question_id': 393489009},
#  {'image_id': 393489,
#   'question': 'Is the phone broken?',
#   'question_id': 393489010},
#  {'image_id': 393489,
#   'question': 'What does this controller go with?',
#   'question_id': 393489011},
#  {'image_id': 393489,
#   'question': 'Is the phone light on?',
#   'question_id': 393489012},
#  {'image_id': 393489,
#   'question': 'Which hand is the person holding the phone in?',
#   'question_id': 393489013},
#  {'image_id': 393489,
#   'question': 'Is the display on?',
#   'question_id': 393489014},
#  {'image_id': 393489,
#   'question': 'Is the person using skype?',
#   'question_id': 393489015},
#  {'image_id': 393489,
#   'question': 'How many phones do you see?',
#   'question_id': 393489016},
#  {'image_id': 393489,
#   'question': 'Is the phone on?',
#   'question_id': 393489017},
#  {'image_id': 393489,
#   'question': 'Is the background clear?',
#   'question_id': 393489018},
#  {'image_id': 393489,
#   'question': 'What brand is the phone?',
#   'question_id': 393489019},
#  {'image_id': 393489,
#   'question': 'What kind of phone is this?',
#   'question_id': 393489020},
#  {'image_id': 393489,
#   'question': 'What is the person holding in their hand?',
#   'question_id': 393489021},
#  {'image_id': 393489,
#   'question': 'What is the person holding?',
#   'question_id': 393489022},
#  {'image_id': 336077,
#   'question': 'Is this an inside stadium?',
#   'question_id': 336077000},
#  {'image_id': 336077,
#   'question': 'Is the stadium crowded?',
#   'question_id': 336077001},
#  {'image_id': 336077,
#   'question': 'Is the stadium full?',
#   'question_id': 336077002},
#  {'image_id': 336077,
#   'question': 'Is there a baseball player holding a bat?',
#   'question_id': 336077003},
#  {'image_id': 546179,
#   'question': 'Is this bathroom all white?',
#   'question_id': 546179000},
#  {'image_id': 546179,
#   'question': 'Has the bathroom been renovated recently?',
#   'question_id': 546179001},
#  {'image_id': 546179,
#   'question': "What's on the other side of the shower curtain?",
#   'question_id': 546179002},
#  {'image_id': 546179,
#   'question': 'Are there towels on the ground?',
#   'question_id': 546179003},
#  {'image_id': 546179,
#   'question': 'What color is the shower curtain?',
#   'question_id': 546179004},
#  {'image_id': 546179,
#   'question': 'Does this look clean?',
#   'question_id': 546179005},
#  {'image_id': 546179,
#   'question': 'Where is the shower located?',
#   'question_id': 546179006},
#  {'image_id': 546179,
#   'question': 'Is the shower curtain open?',
#   'question_id': 546179007},
#  {'image_id': 9,
#   'question': 'How many cookies can be seen?',
#   'question_id': 9000},
#  {'image_id': 9,
#   'question': 'What color are the dishes?',
#   'question_id': 9001},
#  {'image_id': 9, 'question': 'What is the green stuff?', 'question_id': 9002},
#  {'image_id': 393493,
#   'question': 'Does this bike have training wheels?',
#   'question_id': 393493000},
#  {'image_id': 393493,
#   'question': 'How many girls are visible?',
#   'question_id': 393493001},
#  {'image_id': 393493,
#   'question': 'Is the picnic table red?',
#   'question_id': 393493002},
#  {'image_id': 131351,
#   'question': 'Is this a clean room?',
#   'question_id': 131351000},
#  {'image_id': 131351,
#   'question': 'How many colors are in the tile?',
#   'question_id': 131351001},
#  {'image_id': 131351,
#   'question': 'What is the floor made of?',
#   'question_id': 131351002},
#  {'image_id': 131351,
#   'question': 'Is this bathroom clean?',
#   'question_id': 131351003},
#  {'image_id': 131351,
#   'question': 'Is the room clean?',
#   'question_id': 131351004},
#  {'image_id': 131351,
#   'question': 'What color is the water in the bathtub?',
#   'question_id': 131351005},
#  {'image_id': 131351,
#   'question': 'Is there a mirror in the bathroom?',
#   'question_id': 131351006},
#  {'image_id': 131351,
#   'question': 'What is the ratio of white tiles to blue?',
#   'question_id': 131351007},
#  {'image_id': 131351,
#   'question': 'Is there a green plant in this room?',
#   'question_id': 131351008},
#  {'image_id': 131351,
#   'question': 'What power tool is present?',
#   'question_id': 131351009},
#  {'image_id': 131351,
#   'question': 'Is this room clean?',
#   'question_id': 131351010},
#  {'image_id': 131352,
#   'question': 'What fruit is present?',
#   'question_id': 131352000},
#  {'image_id': 131352,
#   'question': 'What color are these mattresses?',
#   'question_id': 131352001},
#  {'image_id': 131352,
#   'question': 'Which room is this?',
#   'question_id': 131352002},
#  {'image_id': 524572,
#   'question': 'Where is the cat sitting?',
#   'question_id': 524572000},
#  {'image_id': 524572,
#   'question': 'What do you think the cat is looking at?',
#   'question_id': 524572001},
#  {'image_id': 524572,
#   'question': 'Is the cat trying to catch a bird?',
#   'question_id': 524572002},
#  {'image_id': 112497,
#   'question': 'What utensil is sitting next to the food?',
#   'question_id': 112497000},
#  {'image_id': 112497,
#   'question': 'What is in the jug?',
#   'question_id': 112497001},
#  {'image_id': 112497,
#   'question': 'What is the name of this crusted food?',
#   'question_id': 112497002},
#  {'image_id': 393503,
#   'question': 'What color are the items on the truck?',
#   'question_id': 393503000},
#  {'image_id': 393503,
#   'question': 'Is the writing in French?',
#   'question_id': 393503001},
#  {'image_id': 393503,
#   'question': 'Is this a traveling circus?',
#   'question_id': 393503002},
#  {'image_id': 393503,
#   'question': 'What animal is on the flatbed?',
#   'question_id': 393503003},
#  {'image_id': 393508,
#   'question': 'What room of the house is this?',
#   'question_id': 393508000},
#  {'image_id': 393508,
#   'question': 'What is the floor made out of?',
#   'question_id': 393508001},
#  {'image_id': 393508,
#   'question': 'What do you use the stove for?',
#   'question_id': 393508002},
#  {'image_id': 414639,
#   'question': 'What is the batter wearing on his ankles?',
#   'question_id': 414639000},
#  {'image_id': 414639,
#   'question': 'Are there long lenses?',
#   'question_id': 414639001},
#  {'image_id': 414639,
#   'question': 'What is the crouching man in the mask called?',
#   'question_id': 414639002},
#  {'image_id': 131366,
#   'question': 'How many people are standing next to each other?',
#   'question_id': 131366000},
#  {'image_id': 131366,
#   'question': 'What are the two women carrying?',
#   'question_id': 131366001},
#  {'image_id': 131366,
#   'question': 'What are these people holding?',
#   'question_id': 131366002},
#  {'image_id': 131366,
#   'question': 'How many rackets?',
#   'question_id': 131366003},
#  {'image_id': 131366,
#   'question': 'How many people are in this photo?',
#   'question_id': 131366004},
#  {'image_id': 131366,
#   'question': 'What is the woman wearing on her neck?',
#   'question_id': 131366005},
#  {'image_id': 131366,
#   'question': 'Is everyone wearing long sleeves?',
#   'question_id': 131366006},
#  {'image_id': 131366,
#   'question': 'What sports are they playing?',
#   'question_id': 131366007},
#  {'image_id': 131366,
#   'question': 'What is the approximate time period of this photo?',
#   'question_id': 131366008},
#  {'image_id': 131366,
#   'question': 'How many girls are in the picture?',
#   'question_id': 131366009},
#  {'image_id': 131366,
#   'question': 'Which two are actually playing?',
#   'question_id': 131366010},
#  {'image_id': 131366,
#   'question': 'Are the woman wearing short dresses?',
#   'question_id': 131366011},
#  {'image_id': 131366,
#   'question': 'Is the lady smiling?',
#   'question_id': 131366012},
#  {'image_id': 131366,
#   'question': 'Do they play for Red Sox?',
#   'question_id': 131366013},
#  {'image_id': 131366,
#   'question': 'What are the ladies doing?',
#   'question_id': 131366014},
#  {'image_id': 131366,
#   'question': 'What three letter word, best describes the liquid container on the ground between the two people?',
#   'question_id': 131366015},
#  {'image_id': 131366,
#   'question': 'What does the wall say on the far left?',
#   'question_id': 131366016},
#  {'image_id': 131366,
#   'question': 'Is this a mixed race group?',
#   'question_id': 131366017},
#  {'image_id': 131366,
#   'question': 'Are these people getting reading to go play sports?',
#   'question_id': 131366018},
#  {'image_id': 131366,
#   'question': 'Is there any females?',
#   'question_id': 131366019},
#  {'image_id': 131366,
#   'question': "How many people don't have a skateboard?",
#   'question_id': 131366020},
#  {'image_id': 131366,
#   'question': 'How many of the four main individuals are wearing baseball caps?',
#   'question_id': 131366021},
#  {'image_id': 131366,
#   'question': 'How many racquets?',
#   'question_id': 131366022},
#  {'image_id': 131366,
#   'question': 'What is the woman wearing?',
#   'question_id': 131366023},
#  {'image_id': 131366,
#   'question': 'What type of photo is this?',
#   'question_id': 131366024},
#  {'image_id': 131366, 'question': 'Is this a shop?', 'question_id': 131366025},
#  {'image_id': 131366,
#   'question': 'What sport is this?',
#   'question_id': 131366026},
#  {'image_id': 131366,
#   'question': 'What are the people holding?',
#   'question_id': 131366027},
#  {'image_id': 131366,
#   'question': 'How many legs are in the image?',
#   'question_id': 131366028},
#  {'image_id': 131366,
#   'question': 'What is the group of people holding in their hand?',
#   'question_id': 131366029},
#  {'image_id': 131366, 'question': 'Are they happy?', 'question_id': 131366030},
#  {'image_id': 131366,
#   'question': 'Is the game live or on television?',
#   'question_id': 131366031},
#  {'image_id': 497565,
#   'question': 'Are the trying to fix the train?',
#   'question_id': 497565000},
#  {'image_id': 497565,
#   'question': 'What color is the locomotive?',
#   'question_id': 497565001},
#  {'image_id': 497565,
#   'question': 'Is the train black?',
#   'question_id': 497565002},
#  {'image_id': 101431,
#   'question': 'Is this an evening scene?',
#   'question_id': 101431000},
#  {'image_id': 101431,
#   'question': 'What color is the sky?',
#   'question_id': 101431001},
#  {'image_id': 101431,
#   'question': 'Is this a desert scene?',
#   'question_id': 101431002},
#  {'image_id': 262442,
#   'question': 'How many passengers does this bus carry?',
#   'question_id': 262442000},
#  {'image_id': 262442,
#   'question': 'Is this a city street?',
#   'question_id': 262442001},
#  {'image_id': 262442,
#   'question': 'How would you call for more information about the bus?',
#   'question_id': 262442002},
#  {'image_id': 262442,
#   'question': 'Which direction is the turn lane going?',
#   'question_id': 262442003},
#  {'image_id': 21895,
#   'question': 'Is she wearing a bonnet?',
#   'question_id': 21895000},
#  {'image_id': 21895,
#   'question': "Was the woman's collar treated with starch?",
#   'question_id': 21895001},
#  {'image_id': 21895,
#   'question': 'What pattern does the woman have on?',
#   'question_id': 21895002},
#  {'image_id': 131373, 'question': 'Where is this?', 'question_id': 131373000},
#  {'image_id': 131373,
#   'question': 'Is it going to storm?',
#   'question_id': 131373001},
#  {'image_id': 131373,
#   'question': 'What kind of animal is on the beach?',
#   'question_id': 131373002},
#  {'image_id': 131373,
#   'question': 'What is running across the beach?',
#   'question_id': 131373003},
#  {'image_id': 131374,
#   'question': 'How many open umbrellas are there on the beach?',
#   'question_id': 131374000},
#  {'image_id': 131374,
#   'question': 'How many umbrellas do you see?',
#   'question_id': 131374001},
#  {'image_id': 131374,
#   'question': 'What is causing the smoke?',
#   'question_id': 131374002},
#  {'image_id': 131374,
#   'question': 'How many striped objects are in the photo?',
#   'question_id': 131374003},
#  {'image_id': 109277,
#   'question': 'What ethnicity is the man?',
#   'question_id': 109277000},
#  {'image_id': 109277,
#   'question': 'What color is the carpet in the middle of the floor?',
#   'question_id': 109277001},
#  {'image_id': 109277,
#   'question': 'Does this room have a low ceiling?',
#   'question_id': 109277002},
#  {'image_id': 131376,
#   'question': 'What color hat is this man wearing?',
#   'question_id': 131376000},
#  {'image_id': 131376,
#   'question': 'What color are the shoelaces?',
#   'question_id': 131376001},
#  {'image_id': 131376,
#   'question': 'Is the man wearing shorts or pants?',
#   'question_id': 131376002},
#  {'image_id': 131376,
#   'question': 'Is a person wearing a hooded sweatshirt?',
#   'question_id': 131376003},
#  {'image_id': 131376,
#   'question': 'Is he wearing a helmet?',
#   'question_id': 131376004},
#  {'image_id': 131376,
#   'question': "Which way is the man's hat facing?",
#   'question_id': 131376005},
#  {'image_id': 131376,
#   'question': "What color is the guy's shirt?",
#   'question_id': 131376006},
#  ...]

# %%
# Extract the 'questions' parameter
questions_data = questions_data['questions']

# Create a DataFrame from the 'questions' data
questions_df = pd.DataFrame(questions_data)
questions_df.sort_values(by='image_id',inplace=True)

# %%
questions_df.to_csv('train_questions.csv',index=False)

# %% [markdown]
# Filter out the rows to store only the questions corresponding to the images in the sampled dataset

# %%
sampled_questions_df  = questions_df[questions_df['image_id'].apply(custom_hash).isin(random_indices)].reset_index(drop=True)

# %%
sampled_questions_df.to_csv('sampled_train_questions.csv',index=False)

# %% [markdown]
# ### Store the answers in CSV format

# %%
# Read the JSON file
with open('v2_Annotations_Train_mscoco//v2_mscoco_train2014_annotations.json', 'r') as f:
    annotations_data = json.load(f)

# %%
annotations_data
# Out:
# [{'question_type': 'what is this',
#   'multiple_choice_answer': 'net',
#   'answers': [{'answer': 'net', 'answer_confidence': 'maybe', 'answer_id': 1},
#    {'answer': 'net', 'answer_confidence': 'yes', 'answer_id': 2},
#    {'answer': 'net', 'answer_confidence': 'yes', 'answer_id': 3},
#    {'answer': 'netting', 'answer_confidence': 'yes', 'answer_id': 4},
#    {'answer': 'net', 'answer_confidence': 'yes', 'answer_id': 5},
#    {'answer': 'net', 'answer_confidence': 'yes', 'answer_id': 6},
#    {'answer': 'mesh', 'answer_confidence': 'maybe', 'answer_id': 7},
#    {'answer': 'net', 'answer_confidence': 'yes', 'answer_id': 8},
#    {'answer': 'net', 'answer_confidence': 'yes', 'answer_id': 9},
#    {'answer': 'net', 'answer_confidence': 'yes', 'answer_id': 10}],
#   'image_id': 458752,
#   'answer_type': 'other',
#   'question_id': 458752000},
#  {'question_type': 'what',
#   'multiple_choice_answer': 'pitcher',
#   'answers': [{'answer': 'pitcher',
#     'answer_confidence': 'yes',
#     'answer_id': 1},
#    {'answer': 'catcher', 'answer_confidence': 'no', 'answer_id': 2},
#    {'answer': 'pitcher', 'answer_confidence': 'yes', 'answer_id': 3},
#    {'answer': 'pitcher', 'answer_confidence': 'yes', 'answer_id': 4},
#    {'answer': 'pitcher', 'answer_confidence': 'yes', 'answer_id': 5},
#    {'answer': 'pitcher', 'answer_confidence': 'yes', 'answer_id': 6},
#    {'answer': 'pitcher', 'answer_confidence': 'yes', 'answer_id': 7},
#    {'answer': 'pitcher', 'answer_confidence': 'yes', 'answer_id': 8},
#    {'answer': 'pitcher', 'answer_confidence': 'yes', 'answer_id': 9},
#    {'answer': 'pitcher', 'answer_confidence': 'yes', 'answer_id': 10}],
#   'image_id': 458752,
#   'answer_type': 'other',
#   'question_id': 458752001},
#  {'answer_type': 'other',
#   'multiple_choice_answer': 'orange',
#   'answers': [{'answer': 'orange', 'answer_confidence': 'yes', 'answer_id': 1},
#    {'answer': 'orange', 'answer_confidence': 'yes', 'answer_id': 2},
#    {'answer': 'orange', 'answer_confidence': 'maybe', 'answer_id': 3},
#    {'answer': 'orange', 'answer_confidence': 'yes', 'answer_id': 4},
#    {'answer': 'orange', 'answer_confidence': 'yes', 'answer_id': 5},
#    {'answer': 'orange', 'answer_confidence': 'yes', 'answer_id': 6},
#    {'answer': 'orange', 'answer_confidence': 'yes', 'answer_id': 7},
#    {'answer': 'orange', 'answer_confidence': 'yes', 'answer_id': 8},
#    {'answer': 'orange', 'answer_confidence': 'yes', 'answer_id': 9},
#    {'answer': 'orange', 'answer_confidence': 'yes', 'answer_id': 10}],
#   'image_id': 458752,
#   'question_type': 'what color is the',
#   'question_id': 458752002},
#  {'question_type': 'is this',
#   'multiple_choice_answer': 'yes',
#   'answers': [{'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 1},
#    {'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 2},
#    {'answer': 'yes', 'answer_confidence': 'maybe', 'answer_id': 3},
#    {'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 4},
#    {'answer': 'yes', 'answer_confidence': 'maybe', 'answer_id': 5},
#    {'answer': 'no', 'answer_confidence': 'maybe', 'answer_id': 6},
#    {'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 7},
#    {'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 8},
#    {'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 9},
#    {'answer': 'yes', 'answer_confidence': 'maybe', 'answer_id': 10}],
#   'image_id': 458752,
#   'answer_type': 'yes/no',
#   'question_id': 458752003},
#  {'question_type': 'what color is the',
#   'multiple_choice_answer': 'white',
#   'answers': [{'answer': 'white', 'answer_confidence': 'yes', 'answer_id': 1},
#    {'answer': 'white', 'answer_confidence': 'yes', 'answer_id': 2},
#    {'answer': 'white', 'answer_confidence': 'yes', 'answer_id': 3},
#    {'answer': 'white', 'answer_confidence': 'yes', 'answer_id': 4},
#    {'answer': 'white', 'answer_confidence': 'yes', 'answer_id': 5},
#    {'answer': 'white', 'answer_confidence': 'yes', 'answer_id': 6},
#    {'answer': 'white', 'answer_confidence': 'yes', 'answer_id': 7},
#    {'answer': 'white', 'answer_confidence': 'yes', 'answer_id': 8},
#    {'answer': 'white', 'answer_confidence': 'yes', 'answer_id': 9},
#    {'answer': 'white', 'answer_confidence': 'yes', 'answer_id': 10}],
#   'image_id': 262146,
#   'answer_type': 'other',
#   'question_id': 262146000},
#  {'question_type': 'what is the person',
#   'multiple_choice_answer': 'skiing',
#   'answers': [{'answer': 'skiing', 'answer_confidence': 'yes', 'answer_id': 1},
#    {'answer': 'skiing', 'answer_confidence': 'yes', 'answer_id': 2},
#    {'answer': 'skiing', 'answer_confidence': 'yes', 'answer_id': 3},
#    {'answer': 'skiing', 'answer_confidence': 'yes', 'answer_id': 4},
#    {'answer': 'skiing', 'answer_confidence': 'yes', 'answer_id': 5},
#    {'answer': 'skiing', 'answer_confidence': 'yes', 'answer_id': 6},
#    {'answer': 'skiing', 'answer_confidence': 'yes', 'answer_id': 7},
#    {'answer': 'skiing', 'answer_confidence': 'yes', 'answer_id': 8},
#    {'answer': 'skiing', 'answer_confidence': 'yes', 'answer_id': 9},
#    {'answer': 'skiing', 'answer_confidence': 'yes', 'answer_id': 10}],
#   'image_id': 262146,
#   'answer_type': 'other',
#   'question_id': 262146001},
#  {'question_type': 'what color is the',
#   'multiple_choice_answer': 'red',
#   'answers': [{'answer': 'red', 'answer_confidence': 'yes', 'answer_id': 1},
#    {'answer': 'red', 'answer_confidence': 'yes', 'answer_id': 2},
#    {'answer': 'red & white', 'answer_confidence': 'yes', 'answer_id': 3},
#    {'answer': 'black', 'answer_confidence': 'no', 'answer_id': 4},
#    {'answer': 'red', 'answer_confidence': 'yes', 'answer_id': 5},
#    {'answer': 'red', 'answer_confidence': 'yes', 'answer_id': 6},
#    {'answer': 'red', 'answer_confidence': 'yes', 'answer_id': 7},
#    {'answer': 'red', 'answer_confidence': 'maybe', 'answer_id': 8},
#    {'answer': 'red', 'answer_confidence': 'yes', 'answer_id': 9},
#    {'answer': 'red and white', 'answer_confidence': 'yes', 'answer_id': 10}],
#   'image_id': 262146,
#   'answer_type': 'other',
#   'question_id': 262146002},
#  {'question_type': 'what is in the',
#   'multiple_choice_answer': 'frisbee',
#   'answers': [{'answer': 'frisbee',
#     'answer_confidence': 'yes',
#     'answer_id': 1},
#    {'answer': 'frisbee', 'answer_confidence': 'yes', 'answer_id': 2},
#    {'answer': 'white frisbee', 'answer_confidence': 'yes', 'answer_id': 3},
#    {'answer': 'frisbie', 'answer_confidence': 'yes', 'answer_id': 4},
#    {'answer': 'frisbee', 'answer_confidence': 'yes', 'answer_id': 5},
#    {'answer': 'frisbee', 'answer_confidence': 'yes', 'answer_id': 6},
#    {'answer': 'frisbee', 'answer_confidence': 'maybe', 'answer_id': 7},
#    {'answer': 'frisbee', 'answer_confidence': 'yes', 'answer_id': 8},
#    {'answer': 'flying disc', 'answer_confidence': 'yes', 'answer_id': 9},
#    {'answer': 'frisbee', 'answer_confidence': 'yes', 'answer_id': 10}],
#   'image_id': 524291,
#   'answer_type': 'other',
#   'question_id': 524291000},
#  {'question_type': 'is the',
#   'multiple_choice_answer': 'yes',
#   'answers': [{'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 1},
#    {'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 2},
#    {'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 3},
#    {'answer': 'yes', 'answer_confidence': 'maybe', 'answer_id': 4},
#    {'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 5},
#    {'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 6},
#    {'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 7},
#    {'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 8},
#    {'answer': 'yes', 'answer_confidence': 'maybe', 'answer_id': 9},
#    {'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 10}],
#   'image_id': 524291,
#   'answer_type': 'yes/no',
#   'question_id': 524291001},
#  {'question_type': 'is the',
#   'multiple_choice_answer': 'frisbee',
#   'answers': [{'answer': 'frisbee',
#     'answer_confidence': 'yes',
#     'answer_id': 1},
#    {'answer': 'frisbee', 'answer_confidence': 'yes', 'answer_id': 2},
#    {'answer': 'frisbee', 'answer_confidence': 'yes', 'answer_id': 3},
#    {'answer': 'frisbee', 'answer_confidence': 'yes', 'answer_id': 4},
#    {'answer': 'frisbee', 'answer_confidence': 'yes', 'answer_id': 5},
#    {'answer': 'frisbee', 'answer_confidence': 'yes', 'answer_id': 6},
#    {'answer': 'frisbee', 'answer_confidence': 'yes', 'answer_id': 7},
#    {'answer': 'frisbee', 'answer_confidence': 'yes', 'answer_id': 8},
#    {'answer': 'frisbee', 'answer_confidence': 'yes', 'answer_id': 9},
#    {'answer': 'frisbee', 'answer_confidence': 'yes', 'answer_id': 10}],
#   'image_id': 524291,
#   'answer_type': 'other',
#   'question_id': 524291002},
#  {'question_type': 'is the',
#   'multiple_choice_answer': 'yes',
#   'answers': [{'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 1},
#    {'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 2},
#    {'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 3},
#    {'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 4},
#    {'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 5},
#    {'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 6},
#    {'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 7},
#    {'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 8},
#    {'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 9},
#    {'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 10}],
#   'image_id': 393221,
#   'answer_type': 'yes/no',
#   'question_id': 393221000},
#  {'question_type': 'is there',
#   'multiple_choice_answer': 'yes',
#   'answers': [{'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 1},
#    {'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 2},
#    {'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 3},
#    {'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 4},
#    {'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 5},
#    {'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 6},
#    {'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 7},
#    {'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 8},
#    {'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 9},
#    {'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 10}],
#   'image_id': 393221,
#   'answer_type': 'yes/no',
#   'question_id': 393221001},
#  {'question_type': 'what is the',
#   'multiple_choice_answer': 'contrail',
#   'answers': [{'answer': 'airplane',
#     'answer_confidence': 'maybe',
#     'answer_id': 1},
#    {'answer': 'plane trail', 'answer_confidence': 'yes', 'answer_id': 2},
#    {'answer': 'contrail', 'answer_confidence': 'yes', 'answer_id': 3},
#    {'answer': 'jet trail', 'answer_confidence': 'maybe', 'answer_id': 4},
#    {'answer': 'snow', 'answer_confidence': 'yes', 'answer_id': 5},
#    {'answer': 'contrails', 'answer_confidence': 'yes', 'answer_id': 6},
#    {'answer': 'jet stream', 'answer_confidence': 'yes', 'answer_id': 7},
#    {'answer': 'air trail', 'answer_confidence': 'maybe', 'answer_id': 8},
#    {'answer': 'jet stream', 'answer_confidence': 'maybe', 'answer_id': 9},
#    {'answer': 'contrail', 'answer_confidence': 'yes', 'answer_id': 10}],
#   'image_id': 393221,
#   'answer_type': 'other',
#   'question_id': 393221002},
#  {'question_type': 'is the',
#   'multiple_choice_answer': 'yes',
#   'answers': [{'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 1},
#    {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 2},
#    {'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 3},
#    {'answer': 'no', 'answer_confidence': 'maybe', 'answer_id': 4},
#    {'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 5},
#    {'answer': 'yes', 'answer_confidence': 'maybe', 'answer_id': 6},
#    {'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 7},
#    {'answer': 'yes', 'answer_confidence': 'maybe', 'answer_id': 8},
#    {'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 9},
#    {'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 10}],
#   'image_id': 393223,
#   'answer_type': 'yes/no',
#   'question_id': 393223000},
#  {'answer_type': 'other',
#   'multiple_choice_answer': 'white and purple',
#   'answers': [{'answer': 'white and purple',
#     'answer_confidence': 'yes',
#     'answer_id': 1},
#    {'answer': 'white', 'answer_confidence': 'yes', 'answer_id': 2},
#    {'answer': 'white and purple', 'answer_confidence': 'yes', 'answer_id': 3},
#    {'answer': 'white and purple', 'answer_confidence': 'yes', 'answer_id': 4},
#    {'answer': 'purple and white', 'answer_confidence': 'yes', 'answer_id': 5},
#    {'answer': 'white', 'answer_confidence': 'yes', 'answer_id': 6},
#    {'answer': 'white', 'answer_confidence': 'yes', 'answer_id': 7},
#    {'answer': 'white & lavender', 'answer_confidence': 'yes', 'answer_id': 8},
#    {'answer': 'white and purple', 'answer_confidence': 'yes', 'answer_id': 9},
#    {'answer': 'lavender and white',
#     'answer_confidence': 'yes',
#     'answer_id': 10}],
#   'image_id': 393223,
#   'question_type': 'what color is the',
#   'question_id': 393223001},
#  {'question_type': 'what is the',
#   'multiple_choice_answer': 'brushing teeth',
#   'answers': [{'answer': 'brushing teeth',
#     'answer_confidence': 'yes',
#     'answer_id': 1},
#    {'answer': 'brushing', 'answer_confidence': 'yes', 'answer_id': 2},
#    {'answer': 'brushing their teeth',
#     'answer_confidence': 'yes',
#     'answer_id': 3},
#    {'answer': 'brushing teeth', 'answer_confidence': 'yes', 'answer_id': 4},
#    {'answer': 'brushing teeth', 'answer_confidence': 'yes', 'answer_id': 5},
#    {'answer': 'brushing teeth', 'answer_confidence': 'yes', 'answer_id': 6},
#    {'answer': 'brushing teeth', 'answer_confidence': 'yes', 'answer_id': 7},
#    {'answer': 'brushing teeth', 'answer_confidence': 'yes', 'answer_id': 8},
#    {'answer': 'brushing teeth', 'answer_confidence': 'yes', 'answer_id': 9},
#    {'answer': 'toothbrush', 'answer_confidence': 'yes', 'answer_id': 10}],
#   'image_id': 393223,
#   'answer_type': 'other',
#   'question_id': 393223002},
#  {'question_type': 'is',
#   'multiple_choice_answer': 'yes',
#   'answers': [{'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 1},
#    {'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 2},
#    {'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 3},
#    {'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 4},
#    {'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 5},
#    {'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 6},
#    {'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 7},
#    {'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 8},
#    {'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 9},
#    {'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 10}],
#   'image_id': 393223,
#   'answer_type': 'yes/no',
#   'question_id': 393223003},
#  {'question_type': 'is the man',
#   'multiple_choice_answer': 'no',
#   'answers': [{'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 1},
#    {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 2},
#    {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 3},
#    {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 4},
#    {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 5},
#    {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 6},
#    {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 7},
#    {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 8},
#    {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 9},
#    {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 10}],
#   'image_id': 393224,
#   'answer_type': 'yes/no',
#   'question_id': 393224000},
#  {'answer_type': 'other',
#   'multiple_choice_answer': 'frowning',
#   'answers': [{'answer': 'waiting',
#     'answer_confidence': 'maybe',
#     'answer_id': 1},
#    {'answer': 'standing', 'answer_confidence': 'yes', 'answer_id': 2},
#    {'answer': 'walking', 'answer_confidence': 'yes', 'answer_id': 3},
#    {'answer': 'unknown', 'answer_confidence': 'no', 'answer_id': 4},
#    {'answer': 'frowning', 'answer_confidence': 'yes', 'answer_id': 5},
#    {'answer': 'pouting', 'answer_confidence': 'no', 'answer_id': 6},
#    {'answer': 'walking', 'answer_confidence': 'yes', 'answer_id': 7},
#    {'answer': 'frowning', 'answer_confidence': 'yes', 'answer_id': 8},
#    {'answer': 'frowning', 'answer_confidence': 'yes', 'answer_id': 9},
#    {'answer': 'frowning', 'answer_confidence': 'yes', 'answer_id': 10}],
#   'image_id': 393224,
#   'question_type': 'what is the',
#   'question_id': 393224001},
#  {'answer_type': 'yes/no',
#   'multiple_choice_answer': 'no',
#   'answers': [{'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 1},
#    {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 2},
#    {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 3},
#    {'answer': 'no', 'answer_confidence': 'maybe', 'answer_id': 4},
#    {'answer': 'poorly', 'answer_confidence': 'maybe', 'answer_id': 5},
#    {'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 6},
#    {'answer': 'yes', 'answer_confidence': 'maybe', 'answer_id': 7},
#    {'answer': 'no', 'answer_confidence': 'maybe', 'answer_id': 8},
#    {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 9},
#    {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 10}],
#   'image_id': 393224,
#   'question_type': 'none of the above',
#   'question_id': 393224002},
#  {'answer_type': 'yes/no',
#   'multiple_choice_answer': 'no',
#   'answers': [{'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 1},
#    {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 2},
#    {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 3},
#    {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 4},
#    {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 5},
#    {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 6},
#    {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 7},
#    {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 8},
#    {'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 9},
#    {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 10}],
#   'image_id': 393224,
#   'question_type': 'does the',
#   'question_id': 393224003},
#  {'question_type': 'is this',
#   'multiple_choice_answer': 'no',
#   'answers': [{'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 1},
#    {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 2},
#    {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 3},
#    {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 4},
#    {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 5},
#    {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 6},
#    {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 7},
#    {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 8},
#    {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 9},
#    {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 10}],
#   'image_id': 393224,
#   'answer_type': 'yes/no',
#   'question_id': 393224004},
#  {'question_type': 'is the man',
#   'multiple_choice_answer': 'no',
#   'answers': [{'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 1},
#    {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 2},
#    {'answer': 'no', 'answer_confidence': 'maybe', 'answer_id': 3},
#    {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 4},
#    {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 5},
#    {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 6},
#    {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 7},
#    {'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 8},
#    {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 9},
#    {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 10}],
#   'image_id': 393224,
#   'answer_type': 'yes/no',
#   'question_id': 393224005},
#  {'question_type': 'none of the above',
#   'multiple_choice_answer': 'yes',
#   'answers': [{'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 1},
#    {'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 2},
#    {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 3},
#    {'answer': 'yes', 'answer_confidence': 'maybe', 'answer_id': 4},
#    {'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 5},
#    {'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 6},
#    {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 7},
#    {'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 8},
#    {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 9},
#    {'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 10}],
#   'image_id': 524297,
#   'answer_type': 'yes/no',
#   'question_id': 524297000},
#  {'question_type': 'what',
#   'multiple_choice_answer': 'black and white',
#   'answers': [{'answer': 'black, white',
#     'answer_confidence': 'yes',
#     'answer_id': 1},
#    {'answer': 'black and white', 'answer_confidence': 'yes', 'answer_id': 2},
#    {'answer': 'black and white', 'answer_confidence': 'yes', 'answer_id': 3},
#    {'answer': 'black and white', 'answer_confidence': 'yes', 'answer_id': 4},
#    {'answer': 'white and gray', 'answer_confidence': 'yes', 'answer_id': 5},
#    {'answer': 'black white', 'answer_confidence': 'yes', 'answer_id': 6},
#    {'answer': 'black and white', 'answer_confidence': 'yes', 'answer_id': 7},
#    {'answer': 'black, white, gray',
#     'answer_confidence': 'yes',
#     'answer_id': 8},
#    {'answer': 'black and white', 'answer_confidence': 'yes', 'answer_id': 9},
#    {'answer': 'black and white', 'answer_confidence': 'yes', 'answer_id': 10}],
#   'image_id': 524297,
#   'answer_type': 'other',
#   'question_id': 524297001},
#  {'answer_type': 'yes/no',
#   'multiple_choice_answer': 'no',
#   'answers': [{'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 1},
#    {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 2},
#    {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 3},
#    {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 4},
#    {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 5},
#    {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 6},
#    {'answer': 'no', 'answer_confidence': 'no', 'answer_id': 7},
#    {'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 8},
#    {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 9},
#    {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 10}],
#   'image_id': 524297,
#   'question_type': 'are the',
#   'question_id': 524297002},
#  {'question_type': 'was',
#   'multiple_choice_answer': 'no',
#   'answers': [{'answer': 'no', 'answer_confidence': 'maybe', 'answer_id': 1},
#    {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 2},
#    {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 3},
#    {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 4},
#    {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 5},
#    {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 6},
#    {'answer': 'no', 'answer_confidence': 'maybe', 'answer_id': 7},
#    {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 8},
#    {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 9},
#    {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 10}],
#   'image_id': 524297,
#   'answer_type': 'yes/no',
#   'question_id': 524297003},
#  {'question_type': 'does the',
#   'multiple_choice_answer': 'yes',
#   'answers': [{'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 1},
#    {'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 2},
#    {'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 3},
#    {'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 4},
#    {'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 5},
#    {'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 6},
#    {'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 7},
#    {'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 8},
#    {'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 9},
#    {'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 10}],
#   'image_id': 393227,
#   'answer_type': 'yes/no',
#   'question_id': 393227000},
#  {'question_type': 'what is this',
#   'multiple_choice_answer': 'skateboard',
#   'answers': [{'answer': 'skateboard',
#     'answer_confidence': 'yes',
#     'answer_id': 1},
#    {'answer': 'skateboard', 'answer_confidence': 'yes', 'answer_id': 2},
#    {'answer': 'skateboard', 'answer_confidence': 'yes', 'answer_id': 3},
#    {'answer': 'skateboard', 'answer_confidence': 'yes', 'answer_id': 4},
#    {'answer': 'skateboard', 'answer_confidence': 'yes', 'answer_id': 5},
#    {'answer': 'skateboard', 'answer_confidence': 'yes', 'answer_id': 6},
#    {'answer': 'skateboard', 'answer_confidence': 'yes', 'answer_id': 7},
#    {'answer': 'skateboard', 'answer_confidence': 'yes', 'answer_id': 8},
#    {'answer': 'skateboard', 'answer_confidence': 'yes', 'answer_id': 9},
#    {'answer': 'skateboard', 'answer_confidence': 'yes', 'answer_id': 10}],
#   'image_id': 393227,
#   'answer_type': 'other',
#   'question_id': 393227001},
#  {'answer_type': 'number',
#   'multiple_choice_answer': '1',
#   'answers': [{'answer': '1', 'answer_confidence': 'yes', 'answer_id': 1},
#    {'answer': '1', 'answer_confidence': 'yes', 'answer_id': 2},
#    {'answer': '1', 'answer_confidence': 'maybe', 'answer_id': 3},
#    {'answer': '1', 'answer_confidence': 'yes', 'answer_id': 4},
#    {'answer': '3', 'answer_confidence': 'maybe', 'answer_id': 5},
#    {'answer': '2', 'answer_confidence': 'yes', 'answer_id': 6},
#    {'answer': '1', 'answer_confidence': 'yes', 'answer_id': 7},
#    {'answer': '1', 'answer_confidence': 'yes', 'answer_id': 8},
#    {'answer': '1', 'answer_confidence': 'yes', 'answer_id': 9},
#    {'answer': '1', 'answer_confidence': 'yes', 'answer_id': 10}],
#   'image_id': 393227,
#   'question_type': 'how many',
#   'question_id': 393227002},
#  {'question_type': 'what color is',
#   'multiple_choice_answer': 'blue',
#   'answers': [{'answer': 'backwards',
#     'answer_confidence': 'yes',
#     'answer_id': 1},
#    {'answer': 'blue', 'answer_confidence': 'yes', 'answer_id': 2},
#    {'answer': 'blue', 'answer_confidence': 'yes', 'answer_id': 3},
#    {'answer': 'blue', 'answer_confidence': 'yes', 'answer_id': 4},
#    {'answer': 'blue', 'answer_confidence': 'yes', 'answer_id': 5},
#    {'answer': 'blue', 'answer_confidence': 'yes', 'answer_id': 6},
#    {'answer': 'blue', 'answer_confidence': 'yes', 'answer_id': 7},
#    {'answer': 'blue', 'answer_confidence': 'yes', 'answer_id': 8},
#    {'answer': 'blue', 'answer_confidence': 'yes', 'answer_id': 9},
#    {'answer': 'blue', 'answer_confidence': 'yes', 'answer_id': 10}],
#   'image_id': 393227,
#   'answer_type': 'other',
#   'question_id': 393227003},
#  {'answer_type': 'yes/no',
#   'multiple_choice_answer': 'no',
#   'answers': [{'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 1},
#    {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 2},
#    {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 3},
#    {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 4},
#    {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 5},
#    {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 6},
#    {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 7},
#    {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 8},
#    {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 9},
#    {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 10}],
#   'image_id': 393227,
#   'question_type': 'is the',
#   'question_id': 393227004},
#  {'question_type': 'what color is the',
#   'multiple_choice_answer': 'green',
#   'answers': [{'answer': 'green', 'answer_confidence': 'yes', 'answer_id': 1},
#    {'answer': 'green and black', 'answer_confidence': 'yes', 'answer_id': 2},
#    {'answer': 'green and black', 'answer_confidence': 'yes', 'answer_id': 3},
#    {'answer': 'green', 'answer_confidence': 'yes', 'answer_id': 4},
#    {'answer': 'green and black', 'answer_confidence': 'yes', 'answer_id': 5},
#    {'answer': 'green', 'answer_confidence': 'yes', 'answer_id': 6},
#    {'answer': 'green', 'answer_confidence': 'yes', 'answer_id': 7},
#    {'answer': 'green', 'answer_confidence': 'yes', 'answer_id': 8},
#    {'answer': 'green', 'answer_confidence': 'maybe', 'answer_id': 9},
#    {'answer': 'green', 'answer_confidence': 'yes', 'answer_id': 10}],
#   'image_id': 131084,
#   'answer_type': 'other',
#   'question_id': 131084000},
#  {'question_type': 'is the man',
#   'multiple_choice_answer': 'yes',
#   'answers': [{'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 1},
#    {'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 2},
#    {'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 3},
#    {'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 4},
#    {'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 5},
#    {'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 6},
#    {'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 7},
#    {'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 8},
#    {'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 9},
#    {'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 10}],
#   'image_id': 131084,
#   'answer_type': 'yes/no',
#   'question_id': 131084001},
#  {'question_type': 'what is the man',
#   'multiple_choice_answer': 'motorcycle',
#   'answers': [{'answer': 'motorbike',
#     'answer_confidence': 'yes',
#     'answer_id': 1},
#    {'answer': 'motorcycle', 'answer_confidence': 'yes', 'answer_id': 2},
#    {'answer': 'dirt bike', 'answer_confidence': 'yes', 'answer_id': 3},
#    {'answer': 'motorbike', 'answer_confidence': 'yes', 'answer_id': 4},
#    {'answer': 'motorcycle', 'answer_confidence': 'yes', 'answer_id': 5},
#    {'answer': 'dirt bike', 'answer_confidence': 'yes', 'answer_id': 6},
#    {'answer': 'motorcycle', 'answer_confidence': 'yes', 'answer_id': 7},
#    {'answer': 'motocross bike', 'answer_confidence': 'yes', 'answer_id': 8},
#    {'answer': 'motorcycle', 'answer_confidence': 'yes', 'answer_id': 9},
#    {'answer': 'dirt bike', 'answer_confidence': 'yes', 'answer_id': 10}],
#   'image_id': 131084,
#   'answer_type': 'other',
#   'question_id': 131084002},
#  {'answer_type': 'other',
#   'multiple_choice_answer': 'gray',
#   'answers': [{'answer': 'pillow sham',
#     'answer_confidence': 'yes',
#     'answer_id': 1},
#    {'answer': 'frills', 'answer_confidence': 'yes', 'answer_id': 2},
#    {'answer': 'pillow case', 'answer_confidence': 'yes', 'answer_id': 3},
#    {'answer': 'pillowcases', 'answer_confidence': 'maybe', 'answer_id': 4},
#    {'answer': 'nothing', 'answer_confidence': 'yes', 'answer_id': 5},
#    {'answer': 'gray', 'answer_confidence': 'maybe', 'answer_id': 6},
#    {'answer': 'note', 'answer_confidence': 'maybe', 'answer_id': 7},
#    {'answer': 'cover', 'answer_confidence': 'yes', 'answer_id': 8},
#    {'answer': 'paper', 'answer_confidence': 'yes', 'answer_id': 9},
#    {'answer': 'sign', 'answer_confidence': 'maybe', 'answer_id': 10}],
#   'image_id': 131074,
#   'question_type': 'what is on the',
#   'question_id': 131074000},
#  {'question_type': 'how many',
#   'multiple_choice_answer': '2',
#   'answers': [{'answer': '2', 'answer_confidence': 'yes', 'answer_id': 1},
#    {'answer': '2', 'answer_confidence': 'yes', 'answer_id': 2},
#    {'answer': '2', 'answer_confidence': 'yes', 'answer_id': 3},
#    {'answer': '2', 'answer_confidence': 'yes', 'answer_id': 4},
#    {'answer': '2', 'answer_confidence': 'yes', 'answer_id': 5},
#    {'answer': '2', 'answer_confidence': 'yes', 'answer_id': 6},
#    {'answer': '2', 'answer_confidence': 'yes', 'answer_id': 7},
#    {'answer': '2', 'answer_confidence': 'yes', 'answer_id': 8},
#    {'answer': '2', 'answer_confidence': 'yes', 'answer_id': 9},
#    {'answer': '2', 'answer_confidence': 'yes', 'answer_id': 10}],
#   'image_id': 131074,
#   'answer_type': 'number',
#   'question_id': 131074001},
#  {'question_type': 'are the',
#   'multiple_choice_answer': 'yes',
#   'answers': [{'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 1},
#    {'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 2},
#    {'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 3},
#    {'answer': 'yes', 'answer_confidence': 'maybe', 'answer_id': 4},
#    {'answer': 'no', 'answer_confidence': 'maybe', 'answer_id': 5},
#    {'answer': 'no', 'answer_confidence': 'maybe', 'answer_id': 6},
#    {'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 7},
#    {'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 8},
#    {'answer': 'yes', 'answer_confidence': 'maybe', 'answer_id': 9},
#    {'answer': 'yes', 'answer_confidence': 'maybe', 'answer_id': 10}],
#   'image_id': 131074,
#   'answer_type': 'yes/no',
#   'question_id': 131074002},
#  {'answer_type': 'yes/no',
#   'multiple_choice_answer': 'no',
#   'answers': [{'answer': 'no', 'answer_confidence': 'maybe', 'answer_id': 1},
#    {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 2},
#    {'answer': 'no', 'answer_confidence': 'maybe', 'answer_id': 3},
#    {'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 4},
#    {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 5},
#    {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 6},
#    {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 7},
#    {'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 8},
#    {'answer': 'yes', 'answer_confidence': 'maybe', 'answer_id': 9},
#    {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 10}],
#   'image_id': 131074,
#   'question_type': 'is the',
#   'question_id': 131074003},
#  {'question_type': 'what is',
#   'multiple_choice_answer': 'purse',
#   'answers': [{'answer': 'purse', 'answer_confidence': 'yes', 'answer_id': 1},
#    {'answer': 'purse', 'answer_confidence': 'yes', 'answer_id': 2},
#    {'answer': 'purse', 'answer_confidence': 'yes', 'answer_id': 3},
#    {'answer': 'handbag', 'answer_confidence': 'yes', 'answer_id': 4},
#    {'answer': 'purse', 'answer_confidence': 'yes', 'answer_id': 5},
#    {'answer': 'purse', 'answer_confidence': 'maybe', 'answer_id': 6},
#    {'answer': 'purse', 'answer_confidence': 'yes', 'answer_id': 7},
#    {'answer': 'purse', 'answer_confidence': 'yes', 'answer_id': 8},
#    {'answer': 'purse', 'answer_confidence': 'yes', 'answer_id': 9},
#    {'answer': 'purse', 'answer_confidence': 'yes', 'answer_id': 10}],
#   'image_id': 131074,
#   'answer_type': 'other',
#   'question_id': 131074004},
#  {'answer_type': 'yes/no',
#   'multiple_choice_answer': 'yes',
#   'answers': [{'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 1},
#    {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 2},
#    {'answer': 'yes', 'answer_confidence': 'no', 'answer_id': 3},
#    {'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 4},
#    {'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 5},
#    {'answer': 'no windows', 'answer_confidence': 'yes', 'answer_id': 6},
#    {'answer': 'yes', 'answer_confidence': 'maybe', 'answer_id': 7},
#    {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 8},
#    {'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 9},
#    {'answer': 'yes', 'answer_confidence': 'maybe', 'answer_id': 10}],
#   'image_id': 131074,
#   'question_type': 'are the',
#   'question_id': 131074005},
#  {'question_type': 'what is this',
#   'multiple_choice_answer': 'skiing',
#   'answers': [{'answer': 'skiing', 'answer_confidence': 'yes', 'answer_id': 1},
#    {'answer': 'skiing', 'answer_confidence': 'yes', 'answer_id': 2},
#    {'answer': 'skiing', 'answer_confidence': 'yes', 'answer_id': 3},
#    {'answer': 'skiing', 'answer_confidence': 'yes', 'answer_id': 4},
#    {'answer': 'snow ski', 'answer_confidence': 'yes', 'answer_id': 5},
#    {'answer': 'skiing', 'answer_confidence': 'yes', 'answer_id': 6},
#    {'answer': 'skiing', 'answer_confidence': 'yes', 'answer_id': 7},
#    {'answer': 'skiing', 'answer_confidence': 'yes', 'answer_id': 8},
#    {'answer': 'skiing', 'answer_confidence': 'yes', 'answer_id': 9},
#    {'answer': 'skiing', 'answer_confidence': 'yes', 'answer_id': 10}],
#   'image_id': 393230,
#   'answer_type': 'other',
#   'question_id': 393230000},
#  {'answer_type': 'number',
#   'multiple_choice_answer': '1',
#   'answers': [{'answer': '1', 'answer_confidence': 'yes', 'answer_id': 1},
#    {'answer': '1', 'answer_confidence': 'yes', 'answer_id': 2},
#    {'answer': '1', 'answer_confidence': 'yes', 'answer_id': 3},
#    {'answer': '1', 'answer_confidence': 'yes', 'answer_id': 4},
#    {'answer': '1', 'answer_confidence': 'yes', 'answer_id': 5},
#    {'answer': '1', 'answer_confidence': 'yes', 'answer_id': 6},
#    {'answer': '1', 'answer_confidence': 'yes', 'answer_id': 7},
#    {'answer': 'there is 1 person in this image',
#     'answer_confidence': 'yes',
#     'answer_id': 8},
#    {'answer': '1', 'answer_confidence': 'yes', 'answer_id': 9},
#    {'answer': '1', 'answer_confidence': 'yes', 'answer_id': 10}],
#   'image_id': 393230,
#   'question_type': 'how many people are in',
#   'question_id': 393230001},
#  {'answer_type': 'yes/no',
#   'multiple_choice_answer': 'no',
#   'answers': [{'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 1},
#    {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 2},
#    {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 3},
#    {'answer': 'no', 'answer_confidence': 'maybe', 'answer_id': 4},
#    {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 5},
#    {'answer': 'no', 'answer_confidence': 'maybe', 'answer_id': 6},
#    {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 7},
#    {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 8},
#    {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 9},
#    {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 10}],
#   'image_id': 393230,
#   'question_type': 'is there a',
#   'question_id': 393230002},
#  {'answer_type': 'other',
#   'multiple_choice_answer': 'skiing',
#   'answers': [{'answer': 'skiing', 'answer_confidence': 'yes', 'answer_id': 1},
#    {'answer': 'skiing', 'answer_confidence': 'yes', 'answer_id': 2},
#    {'answer': 'skiing', 'answer_confidence': 'maybe', 'answer_id': 3},
#    {'answer': 'skiing', 'answer_confidence': 'yes', 'answer_id': 4},
#    {'answer': 'skiing', 'answer_confidence': 'yes', 'answer_id': 5},
#    {'answer': 'skiing', 'answer_confidence': 'yes', 'answer_id': 6},
#    {'answer': 'skiing', 'answer_confidence': 'yes', 'answer_id': 7},
#    {'answer': 'skiing', 'answer_confidence': 'yes', 'answer_id': 8},
#    {'answer': 'skiing', 'answer_confidence': 'yes', 'answer_id': 9},
#    {'answer': 'skiing', 'answer_confidence': 'yes', 'answer_id': 10}],
#   'image_id': 393230,
#   'question_type': 'what is the man',
#   'question_id': 393230003},
#  {'answer_type': 'other',
#   'multiple_choice_answer': 'gray',
#   'answers': [{'answer': 'blue and white',
#     'answer_confidence': 'yes',
#     'answer_id': 1},
#    {'answer': 'gray', 'answer_confidence': 'yes', 'answer_id': 2},
#    {'answer': 'gray', 'answer_confidence': 'yes', 'answer_id': 3},
#    {'answer': 'gray', 'answer_confidence': 'yes', 'answer_id': 4},
#    {'answer': 'gray', 'answer_confidence': 'yes', 'answer_id': 5},
#    {'answer': 'gray', 'answer_confidence': 'yes', 'answer_id': 6},
#    {'answer': 'gray', 'answer_confidence': 'yes', 'answer_id': 7},
#    {'answer': 'gray', 'answer_confidence': 'yes', 'answer_id': 8},
#    {'answer': 'gray', 'answer_confidence': 'yes', 'answer_id': 9},
#    {'answer': 'gray', 'answer_confidence': 'yes', 'answer_id': 10}],
#   'image_id': 393230,
#   'question_type': 'what color is the',
#   'question_id': 393230004},
#  {'question_type': 'what is the person',
#   'multiple_choice_answer': 'skis',
#   'answers': [{'answer': 'ski clothes',
#     'answer_confidence': 'yes',
#     'answer_id': 1},
#    {'answer': 'clothes', 'answer_confidence': 'maybe', 'answer_id': 2},
#    {'answer': 'ski clothes', 'answer_confidence': 'yes', 'answer_id': 3},
#    {'answer': 'skis', 'answer_confidence': 'yes', 'answer_id': 4},
#    {'answer': 'clothes', 'answer_confidence': 'maybe', 'answer_id': 5},
#    {'answer': 'snowsuit', 'answer_confidence': 'maybe', 'answer_id': 6},
#    {'answer': 'ski pants and jacket',
#     'answer_confidence': 'yes',
#     'answer_id': 7},
#    {'answer': 'helmet', 'answer_confidence': 'maybe', 'answer_id': 8},
#    {'answer': 'blue jacket and black pants',
#     'answer_confidence': 'yes',
#     'answer_id': 9},
#    {'answer': 'skis', 'answer_confidence': 'yes', 'answer_id': 10}],
#   'image_id': 393230,
#   'answer_type': 'other',
#   'question_id': 393230005},
#  {'answer_type': 'yes/no',
#   'multiple_choice_answer': 'no',
#   'answers': [{'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 1},
#    {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 2},
#    {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 3},
#    {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 4},
#    {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 5},
#    {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 6},
#    {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 7},
#    {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 8},
#    {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 9},
#    {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 10}],
#   'image_id': 393230,
#   'question_type': 'none of the above',
#   'question_id': 393230006},
#  {'answer_type': 'other',
#   'multiple_choice_answer': 'blue',
#   'answers': [{'answer': 'blue', 'answer_confidence': 'yes', 'answer_id': 1},
#    {'answer': 'blue', 'answer_confidence': 'yes', 'answer_id': 2},
#    {'answer': 'blue', 'answer_confidence': 'yes', 'answer_id': 3},
#    {'answer': 'blue', 'answer_confidence': 'yes', 'answer_id': 4},
#    {'answer': 'blue', 'answer_confidence': 'yes', 'answer_id': 5},
#    {'answer': 'blue', 'answer_confidence': 'yes', 'answer_id': 6},
#    {'answer': 'blue', 'answer_confidence': 'yes', 'answer_id': 7},
#    {'answer': 'blue', 'answer_confidence': 'yes', 'answer_id': 8},
#    {'answer': 'blue', 'answer_confidence': 'yes', 'answer_id': 9},
#    {'answer': 'blue and white', 'answer_confidence': 'yes', 'answer_id': 10}],
#   'image_id': 393230,
#   'question_type': 'what color is',
#   'question_id': 393230007},
#  {'answer_type': 'yes/no',
#   'multiple_choice_answer': 'yes',
#   'answers': [{'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 1},
#    {'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 2},
#    {'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 3},
#    {'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 4},
#    {'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 5},
#    {'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 6},
#    {'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 7},
#    {'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 8},
#    {'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 9},
#    {'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 10}],
#   'image_id': 393230,
#   'question_type': 'is it',
#   'question_id': 393230008},
#  {'question_type': 'what is',
#   'multiple_choice_answer': 'poles',
#   'answers': [{'answer': 'poles', 'answer_confidence': 'yes', 'answer_id': 1},
#    {'answer': 'ski poles', 'answer_confidence': 'yes', 'answer_id': 2},
#    {'answer': 'poles', 'answer_confidence': 'yes', 'answer_id': 3},
#    {'answer': 'skis', 'answer_confidence': 'yes', 'answer_id': 4},
#    {'answer': 'ski poles', 'answer_confidence': 'yes', 'answer_id': 5},
#    {'answer': 'ski pole', 'answer_confidence': 'yes', 'answer_id': 6},
#    {'answer': 'pole', 'answer_confidence': 'maybe', 'answer_id': 7},
#    {'answer': 'poles', 'answer_confidence': 'maybe', 'answer_id': 8},
#    {'answer': 'poles', 'answer_confidence': 'yes', 'answer_id': 9},
#    {'answer': 'poles', 'answer_confidence': 'yes', 'answer_id': 10}],
#   'image_id': 393230,
#   'answer_type': 'other',
#   'question_id': 393230009},
#  {'answer_type': 'yes/no',
#   'multiple_choice_answer': 'no',
#   'answers': [{'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 1},
#    {'answer': 'yes', 'answer_confidence': 'maybe', 'answer_id': 2},
#    {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 3},
#    {'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 4},
#    {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 5},
#    {'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 6},
#    {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 7},
#    {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 8},
#    {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 9},
#    {'answer': 'yes', 'answer_confidence': 'maybe', 'answer_id': 10}],
#   'image_id': 393230,
#   'question_type': 'is the person',
#   'question_id': 393230010},
#  {'question_type': 'what is the',
#   'multiple_choice_answer': 'surfboard',
#   'answers': [{'answer': 'surfboard',
#     'answer_confidence': 'yes',
#     'answer_id': 1},
#    {'answer': 'surfboard', 'answer_confidence': 'yes', 'answer_id': 2},
#    {'answer': 'surfboard', 'answer_confidence': 'yes', 'answer_id': 3},
#    {'answer': 'surfboard', 'answer_confidence': 'yes', 'answer_id': 4},
#    {'answer': 'surfboard', 'answer_confidence': 'yes', 'answer_id': 5},
#    {'answer': 'surfboard', 'answer_confidence': 'yes', 'answer_id': 6},
#    {'answer': 'surfboard', 'answer_confidence': 'yes', 'answer_id': 7},
#    {'answer': 'surfboard', 'answer_confidence': 'yes', 'answer_id': 8},
#    {'answer': 'surfboard', 'answer_confidence': 'yes', 'answer_id': 9},
#    {'answer': 'surfing', 'answer_confidence': 'yes', 'answer_id': 10}],
#   'image_id': 131087,
#   'answer_type': 'other',
#   'question_id': 131087000},
#  {'question_type': 'is the',
#   'multiple_choice_answer': 'yes',
#   'answers': [{'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 1},
#    {'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 2},
#    {'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 3},
#    {'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 4},
#    {'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 5},
#    {'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 6},
#    {'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 7},
#    {'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 8},
#    {'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 9},
#    {'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 10}],
#   'image_id': 131087,
#   'answer_type': 'yes/no',
#   'question_id': 131087001},
#  {'answer_type': 'yes/no',
#   'multiple_choice_answer': 'yes',
#   'answers': [{'answer': 'yes', 'answer_confidence': 'maybe', 'answer_id': 1},
#    {'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 2},
#    {'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 3},
#    {'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 4},
#    {'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 5},
#    {'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 6},
#    {'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 7},
#    {'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 8},
#    {'answer': 'yes', 'answer_confidence': 'maybe', 'answer_id': 9},
#    {'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 10}],
#   'image_id': 131087,
#   'question_type': 'is it',
#   'question_id': 131087002},
#  {'question_type': 'is there a',
#   'multiple_choice_answer': 'yes',
#   'answers': [{'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 1},
#    {'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 2},
#    {'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 3},
#    {'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 4},
#    {'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 5},
#    {'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 6},
#    {'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 7},
#    {'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 8},
#    {'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 9},
#    {'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 10}],
#   'image_id': 131087,
#   'answer_type': 'yes/no',
#   'question_id': 131087003},
#  {'answer_type': 'other',
#   'multiple_choice_answer': 'dog',
#   'answers': [{'answer': 'dog on surfboard',
#     'answer_confidence': 'yes',
#     'answer_id': 1},
#    {'answer': 'dog on surfboard', 'answer_confidence': 'yes', 'answer_id': 2},
#    {'answer': 'dog and surfboard', 'answer_confidence': 'yes', 'answer_id': 3},
#    {'answer': 'dog on surfboard', 'answer_confidence': 'yes', 'answer_id': 4},
#    {'answer': 'surfboard', 'answer_confidence': 'maybe', 'answer_id': 5},
#    {'answer': 'surfboard', 'answer_confidence': 'yes', 'answer_id': 6},
#    {'answer': 'surfboard and dog', 'answer_confidence': 'yes', 'answer_id': 7},
#    {'answer': 'dog', 'answer_confidence': 'yes', 'answer_id': 8},
# ...
#  {'question_type': 'what',
#   'multiple_choice_answer': 'polka dot',
#   'answers': [{'answer': 'dots', 'answer_confidence': 'yes', 'answer_id': 1},
#    {'answer': 'polka dot', 'answer_confidence': 'yes', 'answer_id': 2},
#    {'answer': 'polka dots', 'answer_confidence': 'yes', 'answer_id': 3},
#    {'answer': 'polka dot', 'answer_confidence': 'yes', 'answer_id': 4},
#    {'answer': 'polka dot', 'answer_confidence': 'yes', 'answer_id': 5},
#    {'answer': 'polka dot', 'answer_confidence': 'yes', 'answer_id': 6},
#    {'answer': 'polka dots', 'answer_confidence': 'yes', 'answer_id': 7},
#    {'answer': 'dots', 'answer_confidence': 'yes', 'answer_id': 8},
#    {'answer': 'polka dots', 'answer_confidence': 'yes', 'answer_id': 9},
#    {'answer': 'polka dots', 'answer_confidence': 'yes', 'answer_id': 10}],
#   'image_id': 21895,
#   'answer_type': 'other',
#   'question_id': 21895002},
#  {'question_type': 'none of the above',
#   'multiple_choice_answer': 'beach',
#   'answers': [{'answer': 'beach',
#     'answer_confidence': 'maybe',
#     'answer_id': 1},
#    {'answer': 'beach', 'answer_confidence': 'yes', 'answer_id': 2},
#    {'answer': 'beach', 'answer_confidence': 'yes', 'answer_id': 3},
#    {'answer': 'beach', 'answer_confidence': 'yes', 'answer_id': 4},
#    {'answer': 'beach', 'answer_confidence': 'yes', 'answer_id': 5},
#    {'answer': 'beach', 'answer_confidence': 'yes', 'answer_id': 6},
#    {'answer': 'beach', 'answer_confidence': 'yes', 'answer_id': 7},
#    {'answer': 'beach', 'answer_confidence': 'yes', 'answer_id': 8},
#    {'answer': 'beach', 'answer_confidence': 'yes', 'answer_id': 9},
#    {'answer': 'ocean', 'answer_confidence': 'maybe', 'answer_id': 10}],
#   'image_id': 131373,
#   'answer_type': 'other',
#   'question_id': 131373000},
#  {'question_type': 'is it',
#   'multiple_choice_answer': 'no',
#   'answers': [{'answer': 'yes', 'answer_confidence': 'maybe', 'answer_id': 1},
#    {'answer': 'yes', 'answer_confidence': 'maybe', 'answer_id': 2},
#    {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 3},
#    {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 4},
#    {'answer': 'yes', 'answer_confidence': 'yes', 'answer_id': 5},
#    {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 6},
#    {'answer': 'no', 'answer_confidence': 'maybe', 'answer_id': 7},
#    {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 8},
#    {'answer': 'no', 'answer_confidence': 'maybe', 'answer_id': 9},
#    {'answer': 'yes', 'answer_confidence': 'maybe', 'answer_id': 10}],
#   'image_id': 131373,
#   'answer_type': 'yes/no',
#   'question_id': 131373001},
#  {'answer_type': 'other',
#   'multiple_choice_answer': 'horse',
#   'answers': [{'answer': 'horse', 'answer_confidence': 'yes', 'answer_id': 1},
#    {'answer': 'horse', 'answer_confidence': 'yes', 'answer_id': 2},
#    {'answer': 'horse', 'answer_confidence': 'maybe', 'answer_id': 3},
#    {'answer': 'horse', 'answer_confidence': 'yes', 'answer_id': 4},
#    {'answer': 'horse', 'answer_confidence': 'yes', 'answer_id': 5},
#    {'answer': 'horse', 'answer_confidence': 'yes', 'answer_id': 6},
#    {'answer': 'horse', 'answer_confidence': 'yes', 'answer_id': 7},
#    {'answer': 'horse', 'answer_confidence': 'yes', 'answer_id': 8},
#    {'answer': 'horse', 'answer_confidence': 'yes', 'answer_id': 9},
#    {'answer': 'horse', 'answer_confidence': 'yes', 'answer_id': 10}],
#   'image_id': 131373,
#   'question_type': 'what kind of',
#   'question_id': 131373002},
#  {'question_type': 'what is',
#   'multiple_choice_answer': 'horse',
#   'answers': [{'answer': 'horse', 'answer_confidence': 'yes', 'answer_id': 1},
#    {'answer': 'horse', 'answer_confidence': 'yes', 'answer_id': 2},
#    {'answer': 'horse', 'answer_confidence': 'yes', 'answer_id': 3},
#    {'answer': 'horse', 'answer_confidence': 'yes', 'answer_id': 4},
#    {'answer': 'horse', 'answer_confidence': 'yes', 'answer_id': 5},
#    {'answer': 'horse', 'answer_confidence': 'yes', 'answer_id': 6},
#    {'answer': 'horse', 'answer_confidence': 'yes', 'answer_id': 7},
#    {'answer': 'horse', 'answer_confidence': 'yes', 'answer_id': 8},
#    {'answer': 'horse', 'answer_confidence': 'yes', 'answer_id': 9},
#    {'answer': 'horse', 'answer_confidence': 'yes', 'answer_id': 10}],
#   'image_id': 131373,
#   'answer_type': 'other',
#   'question_id': 131373003},
#  {'answer_type': 'number',
#   'multiple_choice_answer': '3',
#   'answers': [{'answer': '3', 'answer_confidence': 'yes', 'answer_id': 1},
#    {'answer': '4', 'answer_confidence': 'yes', 'answer_id': 2},
#    {'answer': '3', 'answer_confidence': 'yes', 'answer_id': 3},
#    {'answer': '3', 'answer_confidence': 'yes', 'answer_id': 4},
#    {'answer': '3', 'answer_confidence': 'yes', 'answer_id': 5},
#    {'answer': '4', 'answer_confidence': 'maybe', 'answer_id': 6},
#    {'answer': '3', 'answer_confidence': 'yes', 'answer_id': 7},
#    {'answer': '3', 'answer_confidence': 'yes', 'answer_id': 8},
#    {'answer': '4', 'answer_confidence': 'yes', 'answer_id': 9},
#    {'answer': '3', 'answer_confidence': 'yes', 'answer_id': 10}],
#   'image_id': 131374,
#   'question_type': 'how many',
#   'question_id': 131374000},
#  {'question_type': 'how many',
#   'multiple_choice_answer': '3',
#   'answers': [{'answer': '5', 'answer_confidence': 'maybe', 'answer_id': 1},
#    {'answer': '3', 'answer_confidence': 'maybe', 'answer_id': 2},
#    {'answer': '3', 'answer_confidence': 'yes', 'answer_id': 3},
#    {'answer': '4', 'answer_confidence': 'yes', 'answer_id': 4},
#    {'answer': '3', 'answer_confidence': 'yes', 'answer_id': 5},
#    {'answer': '5', 'answer_confidence': 'yes', 'answer_id': 6},
#    {'answer': '4', 'answer_confidence': 'maybe', 'answer_id': 7},
#    {'answer': '4', 'answer_confidence': 'yes', 'answer_id': 8},
#    {'answer': '3', 'answer_confidence': 'yes', 'answer_id': 9},
#    {'answer': '3', 'answer_confidence': 'maybe', 'answer_id': 10}],
#   'image_id': 131374,
#   'answer_type': 'number',
#   'question_id': 131374001},
#  {'question_type': 'what is',
#   'multiple_choice_answer': 'grill',
#   'answers': [{'answer': 'grill',
#     'answer_confidence': 'maybe',
#     'answer_id': 1},
#    {'answer': 'brush fire', 'answer_confidence': 'maybe', 'answer_id': 2},
#    {'answer': 'grill', 'answer_confidence': 'yes', 'answer_id': 3},
#    {'answer': 'grill', 'answer_confidence': 'yes', 'answer_id': 4},
#    {'answer': 'fire', 'answer_confidence': 'maybe', 'answer_id': 5},
#    {'answer': 'grill', 'answer_confidence': 'yes', 'answer_id': 6},
#    {'answer': 'bbq', 'answer_confidence': 'yes', 'answer_id': 7},
#    {'answer': 'grill', 'answer_confidence': 'yes', 'answer_id': 8},
#    {'answer': 'barbeque', 'answer_confidence': 'yes', 'answer_id': 9},
#    {'answer': 'fire', 'answer_confidence': 'yes', 'answer_id': 10}],
#   'image_id': 131374,
#   'answer_type': 'other',
#   'question_id': 131374002},
#  {'question_type': 'how many',
#   'multiple_choice_answer': '4',
#   'answers': [{'answer': '4', 'answer_confidence': 'yes', 'answer_id': 1},
#    {'answer': '4', 'answer_confidence': 'maybe', 'answer_id': 2},
#    {'answer': '3', 'answer_confidence': 'yes', 'answer_id': 3},
#    {'answer': '7', 'answer_confidence': 'maybe', 'answer_id': 4},
#    {'answer': '3', 'answer_confidence': 'yes', 'answer_id': 5},
#    {'answer': '4', 'answer_confidence': 'maybe', 'answer_id': 6},
#    {'answer': '3', 'answer_confidence': 'maybe', 'answer_id': 7},
#    {'answer': '4', 'answer_confidence': 'yes', 'answer_id': 8},
#    {'answer': '3', 'answer_confidence': 'yes', 'answer_id': 9},
#    {'answer': '4', 'answer_confidence': 'yes', 'answer_id': 10}],
#   'image_id': 131374,
#   'answer_type': 'number',
#   'question_id': 131374003},
#  {'question_type': 'what',
#   'multiple_choice_answer': 'african american',
#   'answers': [{'answer': 'african',
#     'answer_confidence': 'yes',
#     'answer_id': 1},
#    {'answer': 'black', 'answer_confidence': 'yes', 'answer_id': 2},
#    {'answer': 'african-american', 'answer_confidence': 'yes', 'answer_id': 3},
#    {'answer': 'african american', 'answer_confidence': 'yes', 'answer_id': 4},
#    {'answer': 'african', 'answer_confidence': 'maybe', 'answer_id': 5},
#    {'answer': 'african american', 'answer_confidence': 'yes', 'answer_id': 6},
#    {'answer': 'black', 'answer_confidence': 'maybe', 'answer_id': 7},
#    {'answer': 'black', 'answer_confidence': 'yes', 'answer_id': 8},
#    {'answer': 'african american', 'answer_confidence': 'yes', 'answer_id': 9},
#    {'answer': 'african', 'answer_confidence': 'yes', 'answer_id': 10}],
#   'image_id': 109277,
#   'answer_type': 'other',
#   'question_id': 109277000},
#  {'question_type': 'what color is the',
#   'multiple_choice_answer': 'blue',
#   'answers': [{'answer': 'blue', 'answer_confidence': 'yes', 'answer_id': 1},
#    {'answer': 'blue', 'answer_confidence': 'yes', 'answer_id': 2},
#    {'answer': 'blue', 'answer_confidence': 'yes', 'answer_id': 3},
#    {'answer': 'blue', 'answer_confidence': 'yes', 'answer_id': 4},
#    {'answer': 'blue', 'answer_confidence': 'yes', 'answer_id': 5},
#    {'answer': 'blue', 'answer_confidence': 'yes', 'answer_id': 6},
#    {'answer': 'blue', 'answer_confidence': 'yes', 'answer_id': 7},
#    {'answer': 'blue and orange', 'answer_confidence': 'yes', 'answer_id': 8},
#    {'answer': 'blue', 'answer_confidence': 'yes', 'answer_id': 9},
#    {'answer': 'blue', 'answer_confidence': 'yes', 'answer_id': 10}],
#   'image_id': 109277,
#   'answer_type': 'other',
#   'question_id': 109277001},
#  {'question_type': 'does this',
#   'multiple_choice_answer': 'no',
#   'answers': [{'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 1},
#    {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 2},
#    {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 3},
#    {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 4},
#    {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 5},
#    {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 6},
#    {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 7},
#    {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 8},
#    {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 9},
#    {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 10}],
#   'image_id': 109277,
#   'answer_type': 'yes/no',
#   'question_id': 109277002},
#  {'answer_type': 'other',
#   'multiple_choice_answer': 'black',
#   'answers': [{'answer': 'black', 'answer_confidence': 'yes', 'answer_id': 1},
#    {'answer': 'black', 'answer_confidence': 'yes', 'answer_id': 2},
#    {'answer': 'black', 'answer_confidence': 'yes', 'answer_id': 3},
#    {'answer': 'black', 'answer_confidence': 'maybe', 'answer_id': 4},
#    {'answer': 'black', 'answer_confidence': 'maybe', 'answer_id': 5},
#    {'answer': 'black', 'answer_confidence': 'maybe', 'answer_id': 6},
#    {'answer': 'black', 'answer_confidence': 'yes', 'answer_id': 7},
#    {'answer': 'brown', 'answer_confidence': 'yes', 'answer_id': 8},
#    {'answer': 'black', 'answer_confidence': 'yes', 'answer_id': 9},
#    {'answer': 'black', 'answer_confidence': 'no', 'answer_id': 10}],
#   'image_id': 131376,
#   'question_type': 'what color',
#   'question_id': 131376000},
#  {'answer_type': 'other',
#   'multiple_choice_answer': 'red',
#   'answers': [{'answer': 'red', 'answer_confidence': 'yes', 'answer_id': 1},
#    {'answer': 'red', 'answer_confidence': 'yes', 'answer_id': 2},
#    {'answer': 'red', 'answer_confidence': 'maybe', 'answer_id': 3},
#    {'answer': 'black', 'answer_confidence': 'maybe', 'answer_id': 4},
#    {'answer': 'black', 'answer_confidence': 'maybe', 'answer_id': 5},
#    {'answer': 'red', 'answer_confidence': 'yes', 'answer_id': 6},
#    {'answer': 'red', 'answer_confidence': 'yes', 'answer_id': 7},
#    {'answer': 'black', 'answer_confidence': 'yes', 'answer_id': 8},
#    {'answer': 'black', 'answer_confidence': 'yes', 'answer_id': 9},
#    {'answer': 'red', 'answer_confidence': 'yes', 'answer_id': 10}],
#   'image_id': 131376,
#   'question_type': 'what color are the',
#   'question_id': 131376001},
#  {'answer_type': 'other',
#   'multiple_choice_answer': 'shorts',
#   'answers': [{'answer': 'shorts', 'answer_confidence': 'yes', 'answer_id': 1},
#    {'answer': 'shorts', 'answer_confidence': 'yes', 'answer_id': 2},
#    {'answer': 'shorts', 'answer_confidence': 'yes', 'answer_id': 3},
#    {'answer': 'pants', 'answer_confidence': 'yes', 'answer_id': 4},
#    {'answer': 'shorts', 'answer_confidence': 'yes', 'answer_id': 5},
#    {'answer': 'pants', 'answer_confidence': 'maybe', 'answer_id': 6},
#    {'answer': 'shorts', 'answer_confidence': 'yes', 'answer_id': 7},
#    {'answer': 'pants', 'answer_confidence': 'yes', 'answer_id': 8},
#    {'answer': 'shorts', 'answer_confidence': 'yes', 'answer_id': 9},
#    {'answer': 'shorts', 'answer_confidence': 'yes', 'answer_id': 10}],
#   'image_id': 131376,
#   'question_type': 'is the man',
#   'question_id': 131376002},
#  {'answer_type': 'yes/no',
#   'multiple_choice_answer': 'no',
#   'answers': [{'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 1},
#    {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 2},
#    {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 3},
#    {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 4},
#    {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 5},
#    {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 6},
#    {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 7},
#    {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 8},
#    {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 9},
#    {'answer': 'no', 'answer_confidence': 'maybe', 'answer_id': 10}],
#   'image_id': 131376,
#   'question_type': 'is',
#   'question_id': 131376003},
#  {'answer_type': 'yes/no',
#   'multiple_choice_answer': 'no',
#   'answers': [{'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 1},
#    {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 2},
#    {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 3},
#    {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 4},
#    {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 5},
#    {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 6},
#    {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 7},
#    {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 8},
#    {'answer': 'no', 'answer_confidence': 'maybe', 'answer_id': 9},
#    {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 10}],
#   'image_id': 131376,
#   'question_type': 'is he',
#   'question_id': 131376004},
#  {'question_type': 'which',
#   'multiple_choice_answer': 'down',
#   'answers': [{'answer': 'down/forward',
#     'answer_confidence': 'maybe',
#     'answer_id': 1},
#    {'answer': 'backwards', 'answer_confidence': 'yes', 'answer_id': 2},
#    {'answer': 'down', 'answer_confidence': 'yes', 'answer_id': 3},
#    {'answer': 'front', 'answer_confidence': 'maybe', 'answer_id': 4},
#    {'answer': 'forward', 'answer_confidence': 'yes', 'answer_id': 5},
#    {'answer': 'backwards', 'answer_confidence': 'yes', 'answer_id': 6},
#    {'answer': 'down', 'answer_confidence': 'yes', 'answer_id': 7},
#    {'answer': 'forward', 'answer_confidence': 'yes', 'answer_id': 8},
#    {'answer': 'forward', 'answer_confidence': 'yes', 'answer_id': 9},
#    {'answer': 'down', 'answer_confidence': 'yes', 'answer_id': 10}],
#   'image_id': 131376,
#   'answer_type': 'other',
#   'question_id': 131376005},
#  {'question_type': 'what color is the',
#   'multiple_choice_answer': 'white',
#   'answers': [{'answer': 'black white',
#     'answer_confidence': 'yes',
#     'answer_id': 1},
#    {'answer': 'white', 'answer_confidence': 'yes', 'answer_id': 2},
#    {'answer': 'white and black', 'answer_confidence': 'yes', 'answer_id': 3},
#    {'answer': 'white', 'answer_confidence': 'yes', 'answer_id': 4},
#    {'answer': 'white', 'answer_confidence': 'yes', 'answer_id': 5},
#    {'answer': 'black and white', 'answer_confidence': 'yes', 'answer_id': 6},
#    {'answer': 'black & white', 'answer_confidence': 'yes', 'answer_id': 7},
#    {'answer': 'black and white', 'answer_confidence': 'yes', 'answer_id': 8},
#    {'answer': 'white and black', 'answer_confidence': 'yes', 'answer_id': 9},
#    {'answer': 'white and black', 'answer_confidence': 'yes', 'answer_id': 10}],
#   'image_id': 131376,
#   'answer_type': 'other',
#   'question_id': 131376006},
#  ...]

# %%
# Create a DataFrame from the 'annotaions' data
annotations_df = pd.DataFrame(annotations_data)
annotations_df.sort_values(by='image_id',inplace=True)

# %%
annotations_df.head()
# Out:
#           question_type multiple_choice_answer  \
# 903         what is the               broccoli
# 902  what color are the        pink and yellow
# 901            how many                      2
# 95               is the                     no
# 94                  are                    yes
#
#                                                answers  image_id answer_type  \
# 903  [{'answer': 'broccoli', 'answer_confidence': '...         9       other
# 902  [{'answer': 'pink and yellow', 'answer_confide...         9       other
# 901  [{'answer': '2', 'answer_confidence': 'yes', '...         9      number
# 95   [{'answer': 'no', 'answer_confidence': 'yes', ...        25      yes/no
# 94   [{'answer': 'yes', 'answer_confidence': 'yes',...        25      yes/no
#
#      question_id
# 903         9002
# 902         9001
# 901         9000
# 95         25013
# 94         25012

# %%
annotations_df.columns
# Out:
# Index(['question_type', 'multiple_choice_answer', 'answers', 'image_id',
#        'answer_type', 'question_id'],
#       dtype='object')

# %%
annotations_df.to_csv('train_annotations.csv',index=False)

# %% [markdown]
# Filter out the rows to store only the questions corresponding to the images in the sampled dataset

# %%
sampled_annotations_df = annotations_df[annotations_df['image_id'].apply(custom_hash).isin(random_indices)].reset_index(drop=True)

# %%
sampled_annotations_df.to_csv('sampled_train_annotaions_df.csv',index=False)

# %%
print(len(sampled_annotations_df),len(sampled_questions_df),len(df))
# Out:
# 109972 109972 82783

# %%
sampled_df.columns , sampled_annotations_df.columns, sampled_questions_df.columns
# Out:
# (Index(['image_name', 'image_path', 'image_id', 'hashed_image_id'], dtype='object'),
#  Index(['question_type', 'multiple_choice_answer', 'answers', 'image_id',
#         'answer_type', 'question_id'],
#        dtype='object'),
#  Index(['image_id', 'question', 'question_id'], dtype='object'))

# %%
sampled_questions_annotations_df = pd.merge(sampled_questions_df, sampled_annotations_df, on=['question_id','image_id'])

# %%
sampled_questions_annotations_df.columns, len(sampled_questions_annotations_df)
# Out:
# (Index(['image_id', 'question', 'question_id', 'question_type',
#         'multiple_choice_answer', 'answers', 'answer_type'],
#        dtype='object'),
#  109972)

# %%
sampled_questions_annotations_df.to_csv('sampled_train_questions_annotations.csv',index=False)

# %%
sampled_train_dataset_df = pd.merge(sampled_questions_annotations_df,sampled_df,on='image_id')

# %%
sampled_train_dataset_df.columns, len(sampled_train_dataset_df)
# Out:
# (Index(['image_id', 'question', 'question_id', 'question_type',
#         'multiple_choice_answer', 'answers', 'answer_type', 'image_name',
#         'image_path', 'hashed_image_id'],
#        dtype='object'),
#  109972)

# %%
sampled_train_dataset_df.to_csv('sampled_train_dataset.csv',index=False)

# %% [markdown]
# ## Delete the images which are not being used for training

# %%
# Path to the folder containing the image files
folder_path = "train2014"

for filename in os.listdir(folder_path):
    # Extract the number from the filename
    number = int(filename.split('_')[-1].split('.')[0])
    
    # Get the hash value of the number
    hash_value = custom_hash(number)
    
    # Check if the hash value is present in the random indices list
    if hash_value not in random_indices:
        # If not present, delete the file
        file_path = os.path.join(folder_path, filename)
        os.remove(file_path)

# %% [markdown]
# Adding a new column to store the relative path in Kaggle

# %%
sampled_train_dataset_kaggle = pd.read_csv('sampled_train_dataset.csv')

def append_string(value):
    return os.path.join('train2014', value)

# Apply the function to each value in the column
sampled_train_dataset_kaggle['kaggle_image_path'] = sampled_train_dataset_kaggle['image_path'].apply(append_string)

# %%
sampled_train_dataset_kaggle.to_csv('sampled_train_dataset_kaggle.csv',index=False)

# %% [markdown]
# ## Understanding the dataset

# %%
import pandas as pd
df = pd.read_csv('sampled_train_dataset.csv')

# %%
df.head()
# Out:
#    image_id                                           question  question_id  \
# 0        25                       Is the giraffe in the shade?        25013
# 1        25                     Are any of the animals eating?        25012
# 2        25                        Are some of the trees dead?        25011
# 3        25  What is on the ground next to the giraffe on t...        25010
# 4        25                                 Are they at a zoo?        25009
#
#     question_type multiple_choice_answer  \
# 0          is the                     no
# 1             are                    yes
# 2             are                    yes
# 3  what is on the                    log
# 4        are they                    yes
#
#                                              answers answer_type  \
# 0  [{'answer': 'no', 'answer_confidence': 'yes', ...      yes/no
# 1  [{'answer': 'yes', 'answer_confidence': 'yes',...      yes/no
# 2  [{'answer': 'yes', 'answer_confidence': 'yes',...      yes/no
# 3  [{'answer': 'log', 'answer_confidence': 'yes',...       other
# 4  [{'answer': 'yes', 'answer_confidence': 'maybe...      yes/no
#
#                         image_name                                 image_path  \
# 0  COCO_train2014_000000000025.jpg  train2014\COCO_train2014_000000000025.jpg
# 1  COCO_train2014_000000000025.jpg  train2014\COCO_train2014_000000000025.jpg
# 2  COCO_train2014_000000000025.jpg  train2014\COCO_train2014_000000000025.jpg
# 3  COCO_train2014_000000000025.jpg  train2014\COCO_train2014_000000000025.jpg
# 4  COCO_train2014_000000000025.jpg  train2014\COCO_train2014_000000000025.jpg
#
#    hashed_image_id
# 0                2
# 1                2
# 2                2
# 3                2
# 4                2

# %%
df['answer_type'].unique()
# Out:
# array(['yes/no', 'other', 'number'], dtype=object)

# %%
answers_test = eval(df['answers'].iloc[0])

# %%
print(answers_test)
# Out:
# [{'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 1}, {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 2}, {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 3}, {'answer': 'no', 'answer_confidence': 'maybe', 'answer_id': 4}, {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 5}, {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 6}, {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 7}, {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 8}, {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 9}, {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 10}]
